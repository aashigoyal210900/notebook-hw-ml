# %% [markdown]
# ### Name: Aashi Arvindkumar Goyal
# ### USC-ID: 8228548352
# ### github username: aashigoyal210900

# %% [markdown]
# ## Pandas
# b) Use the read_csv(...) method from Pandas (Documentation Link) to read data
# from file Salaries.csv and to copy it into a dataframe.

# %%
import pandas as pd

# %% [markdown]
# *From below cell, the read_csv() is used to ready the csv file nad gets laoding in dataframe "data"*

# %%
data = pd.read_csv("Salaries.csv")
data
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# ...       ...    ...  ...        ...       ...
# 25570    2015    WAS   NL  treinbl01    512800
# 25571    2015    WAS   NL  ugglada01    507500
# 25572    2015    WAS   NL  werthja01  21000000
# 25573    2015    WAS   NL  zimmejo02  16500000
# 25574    2015    WAS   NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# (c) Make the column playerID in the csv file as the index column and the first row as the header. Also, skip the second row when reading the file.

# %% [markdown]
# c.1) making playerID column as index column

# %%
data = data.set_index('playerID')
data
# Out:
#            yearID teamID lgID    salary
# playerID
# barkele01    1985    ATL   NL    870000
# bedrost01    1985    ATL   NL    550000
# benedbr01    1985    ATL   NL    545000
# campri01     1985    ATL   NL    633333
# ceronri01    1985    ATL   NL    625000
# ...           ...    ...  ...       ...
# treinbl01    2015    WAS   NL    512800
# ugglada01    2015    WAS   NL    507500
# werthja01    2015    WAS   NL  21000000
# zimmejo02    2015    WAS   NL  16500000
# zimmery01    2015    WAS   NL  14000000
#
# [25575 rows x 4 columns]

# %%
data.to_csv("Salaries.csv")

# %% [markdown]
# c.2) making first row as header

# %%
data.columns = data.iloc[0]
data =data[1:]
data.head()
# Out:
# barkele01  1985  ATL  NL  870000
# playerID
# bedrost01  1985  ATL  NL  550000
# benedbr01  1985  ATL  NL  545000
# campri01   1985  ATL  NL  633333
# ceronri01  1985  ATL  NL  625000
# chambch01  1985  ATL  NL  800000

# %%
data
# Out:
# barkele01  1985  ATL  NL    870000
# playerID
# bedrost01  1985  ATL  NL    550000
# benedbr01  1985  ATL  NL    545000
# campri01   1985  ATL  NL    633333
# ceronri01  1985  ATL  NL    625000
# chambch01  1985  ATL  NL    800000
# ...         ...  ...  ..       ...
# treinbl01  2015  WAS  NL    512800
# ugglada01  2015  WAS  NL    507500
# werthja01  2015  WAS  NL  21000000
# zimmejo02  2015  WAS  NL  16500000
# zimmery01  2015  WAS  NL  14000000
#
# [25574 rows x 4 columns]

# %%
data.to_csv("Salaries.csv")

# %% [markdown]
# c.3) skipping second row while reading file

# %%
data = pd.read_csv("Salaries.csv", skiprows=[2])
data
# Out:
#         playerID  1985  ATL  NL    870000
# 0      bedrost01  1985  ATL  NL    550000
# 1       campri01  1985  ATL  NL    633333
# 2      ceronri01  1985  ATL  NL    625000
# 3      chambch01  1985  ATL  NL    800000
# 4      dedmoje01  1985  ATL  NL    150000
# ...          ...   ...  ...  ..       ...
# 25568  treinbl01  2015  WAS  NL    512800
# 25569  ugglada01  2015  WAS  NL    507500
# 25570  werthja01  2015  WAS  NL  21000000
# 25571  zimmejo02  2015  WAS  NL  16500000
# 25572  zimmery01  2015  WAS  NL  14000000
#
# [25573 rows x 5 columns]

# %% [markdown]
# (d) Select the id of the players who are registered in ATL and HOU whose salary is higher than one million.

# %%
data.columns
# Out:
# Index(['playerID', '1985', 'ATL', 'NL', '870000'], dtype='object')

# %%
print("all id's of players who are registered in ATL and HOU whose salary is higher than one million =>")
result=data[(data.ATL=='ATL') | (data.ATL=='HOU')]
result
result_final = result[(result.iloc[:,4]>1000000)]
result_final
# Out:
# all id's of players who are registered in ATL and HOU whose salary is higher than one million =>
#         playerID  1985  ATL  NL   870000
# 8      hornebo01  1985  ATL  NL  1500000
# 13     murphda05  1985  ATL  NL  1625000
# 18     suttebr01  1985  ATL  NL  1354167
# 214     ryanno01  1985  HOU  NL  1350000
# 557    hornebo01  1986  ATL  NL  1800000
# ...          ...   ...  ...  ..      ...
# 25051  quallch01  2015  HOU  AL  3000000
# 25052  rasmuco01  2015  HOU  AL  8000000
# 25053  singljo02  2015  HOU  AL  2000000
# 25054   sippto01  2015  HOU  AL  2400000
# 25057  valbulu01  2015  HOU  AL  4200000
#
# [595 rows x 5 columns]

# %% [markdown]
# (e) Use the describe() method to calculate the standard deviation, first quartile, median, third quartile, mean, maximum, and minimum of the salary in team ATL

# %%
res_atl= data[data.ATL=='ATL']
res_atl
# Out:
#         playerID  1985  ATL  NL   870000
# 0      bedrost01  1985  ATL  NL   550000
# 1       campri01  1985  ATL  NL   633333
# 2      ceronri01  1985  ATL  NL   625000
# 3      chambch01  1985  ATL  NL   800000
# 4      dedmoje01  1985  ATL  NL   150000
# ...          ...   ...  ...  ..      ...
# 24804  simmoan01  2015  ATL  NL  3000000
# 24805  teherju01  2015  ATL  NL  1000000
# 24806  terdojo01  2015  ATL  NL   507500
# 24807   woodal02  2015  ATL  NL   520000
# 24808  younger03  2015  ATL  NL  1000000
#
# [884 rows x 5 columns]

# %%
res_atl.iloc[:,4].describe()
# Out:
# count    8.840000e+02
# mean     2.209630e+06
# std      3.435808e+06
# min      6.000000e+04
# 25%      3.000000e+05
# 50%      6.000000e+05
# 75%      2.412500e+06
# max      1.606180e+07
# Name: 870000, dtype: float64

# %% [markdown]
# (f) Create a Python dictionary object whose keys are the headers of the dataframe
# created in the read_csv() exercise and values are Python list objects that contain
# data corresponding to the headers. (Here, use the iterrows() method to iterate
# each row of the dataframe and copy it to a dictionary. However, there is an easier
# way. Learn how the to_dict() method works by yourself later)

# %%
data_dict = data.to_dict()
data_dict
# Out:
# {'playerID': {0: 'bedrost01',
#   1: 'campri01',
#   2: 'ceronri01',
#   3: 'chambch01',
#   4: 'dedmoje01',
#   5: 'forstte01',
#   6: 'garbege01',
#   7: 'harpete01',
#   8: 'hornebo01',
#   9: 'hubbagl01',
#   10: 'mahleri01',
#   11: 'mcmurcr01',
#   12: 'mumphje01',
#   13: 'murphda05',
#   14: 'oberkke01',
#   15: 'perezpa01',
#   16: 'perryge01',
#   17: 'ramirra01',
#   18: 'suttebr01',
#   19: 'washicl01',
#   20: 'boddimi01',
#   21: 'dauerri01',
#   22: 'davisst02',
#   23: 'dempsri01',
#   24: 'dwyerji01',
#   25: 'flanami01',
#   26: 'fordda01',
#   27: 'grosswa01',
#   28: 'lacyle01',
#   29: 'lynnfr01',
#   30: 'martide01',
#   31: 'martiti01',
#   32: 'mcgresc01',
#   33: 'murraed02',
#   34: 'nolanjo01',
#   35: 'rayfofl01',
#   36: 'ripkeca01',
#   37: 'roeniga01',
#   38: 'sheetla01',
#   39: 'shelbjo01',
#   40: 'stewasa01',
#   41: 'youngmi01',
#   42: 'armasto01',
#   43: 'barrema02',
#   44: 'boggswa01',
#   45: 'bordiri01',
#   46: 'boydoi01',
#   47: 'bucknbi01',
#   48: 'clearma01',
#   49: 'clemero02',
#   50: 'crawfst01',
#   51: 'easlemi01',
#   52: 'evansdw01',
#   53: 'gedmari01',
#   54: 'gutieja01',
#   55: 'hoffmgl01',
#   56: 'hurstbr01',
#   57: 'juraked01',
#   58: 'kisonbr01',
#   59: 'milleri01',
#   60: 'nichore01',
#   61: 'nippeal01',
#   62: 'ojedabo01',
#   63: 'remyje01',
#   64: 'riceji01',
#   65: 'stanlbo01',
#   66: 'staplda01',
#   67: 'beniqju01',
#   68: 'boonebo01',
#   69: 'burleri01',
#   70: 'candejo01',
#   71: 'carewro01',
#   72: 'clibust02',
#   73: 'corbedo01',
#   74: 'decindo01',
#   75: 'downibr01',
#   76: 'forscke01',
#   77: 'grichbo01',
#   78: 'hendrge01',
#   79: 'hollaal01',
#   80: 'jacksre01',
#   81: 'jonesru01',
#   82: 'lacorfr01',
#   83: 'mccaski01',
#   84: 'mooredo01',
#   85: 'pettiga01',
#   86: 'romanro01',
#   87: 'sanchlu01',
#   88: 'schofdi02',
#   89: 'sconida01',
#   90: 'slatoji01',
#   91: 'suttodo01',
#   92: 'wilforo01',
#   93: 'wittmi01',
#   94: 'zahnge01',
#   95: 'agostju01',
#   96: 'baineha01',
#   97: 'bannifl01',
#   98: 'burnsbr01',
#   99: 'cruzju01',
#   100: 'dotsori01',
#   101: 'fiskca01',
#   102: 'fletcsc01',
#   103: 'guilloz01',
#   104: 'hairsje01',
#   105: 'hillma01',
#   106: 'jamesbo01',
#   107: 'kittlro01',
#   108: 'lawru01',
#   109: 'lollati01',
#   110: 'nelsoge01',
#   111: 'pacioto01',
#   112: 'salazlu01',
#   113: 'seaveto01',
#   114: 'spillda01',
#   115: 'walkegr01',
#   116: 'bosleth01',
#   117: 'brusswa01',
#   118: 'ceyro01',
#   119: 'davisjo02',
#   120: 'dernibo01',
#   121: 'durhale01',
#   122: 'eckerde01',
#   123: 'fontera01',
#   124: 'frazige01',
#   125: 'hebneri01',
#   126: 'lopesda01',
#   127: 'matthga01',
#   128: 'morelke01',
#   129: 'ruthvdi01',
#   130: 'sandbry01',
#   131: 'sandesc01',
#   132: 'smithle02',
#   133: 'sorenla01',
#   134: 'speiech01',
#   135: 'sutclri01',
#   136: 'troutst01',
#   137: 'woodsga01',
#   138: 'bellbu01',
#   139: 'brownto05',
#   140: 'conceda01',
#   141: 'foleyto02',
#   142: 'francjo01',
#   143: 'humeto01',
#   144: 'krencwa01',
#   145: 'mcgafan01',
#   146: 'milneed01',
#   147: 'oestero01',
#   148: 'parkeda01',
#   149: 'pastofr01',
#   150: 'perezto01',
#   151: 'powerte01',
#   152: 'pricejo02',
#   153: 'redusga01',
#   154: 'rosepe01',
#   155: 'sotoma01',
#   156: 'stupejo01',
#   157: 'tibbsja01',
#   158: 'vangoda01',
#   159: 'venabma01',
#   160: 'ayalabe01',
#   161: 'bandoch01',
#   162: 'bernato01',
#   163: 'blylebe01',
#   164: 'butlebr01',
#   165: 'camacer01',
#   166: 'cartejo01',
#   167: 'easteja01',
#   168: 'fischmi01',
#   169: 'francju01',
#   170: 'garlawa01',
#   171: 'hallme01',
#   172: 'hargrmi01',
#   173: 'heatone01',
#   174: 'jacobbr01',
#   175: 'ruhleve01',
#   176: 'tablepa01',
#   177: 'thornan01',
#   178: 'vukovge01',
#   179: 'waddeto01',
#   180: 'berenju01',
#   181: 'bergmda01',
#   182: 'brookto01',
#   183: 'castima02',
#   184: 'evansda01',
#   185: 'gibsoki01',
#   186: 'grubbjo01',
#   187: 'hernawi01',
#   188: 'herndla01',
#   189: 'lapoida01',
#   190: 'lemonch01',
#   191: 'lopezau01',
#   192: 'morrija02',
#   193: 'parrila02',
#   194: 'petryda01',
#   195: 'scherbi01',
#   196: 'terrewa01',
#   197: 'trammal01',
#   198: 'whitalo01',
#   199: 'wilcomi01',
#   200: 'ashbyal01',
#   201: 'basske01',
#   202: 'cabelen01',
#   203: 'cruzjo01',
#   204: 'davisgl01',
#   205: 'dawlebi01',
#   206: 'dipinfr01',
#   207: 'doranbi02',
#   208: 'garneph01',
#   209: 'kneppbo01',
#   210: 'morenom01',
#   211: 'niekrjo01',
#   212: 'puhlte01',
#   213: 'reynocr01',
#   214: 'ryanno01',
#   215: 'scottmi03',
#   216: 'smithda02',
#   217: 'spilmha01',
#   218: 'thondi01',
#   219: 'wallide01',
#   220: 'balbost01',
#   221: 'beckwjo01',
#   222: 'blackbu02',
#   223: 'brettge01',
#   224: 'conceon01',
#   225: 'gubicma01',
#   226: 'jacksda02',
#   227: 'jonesly01',
#   228: 'jonesmi02',
#   229: 'lampde01',
#   230: 'leibrch01',
#   231: 'leonade01',
#   232: 'mcraeha01',
#   233: 'motleda01',
#   234: 'ortajo01',
#   235: 'pryorgr01',
#   236: 'quiseda01',
#   237: 'saberbr01',
#   238: 'sheripa01',
#   239: 'sundbji01',
#   240: 'wathajo01',
#   241: 'wilsowi02',
#   242: 'bailobo01',
#   243: 'brockgr01',
#   244: 'diazca01',
#   245: 'duncama01',
#   246: 'goltzda01',
#   247: 'guerrpe01',
#   248: 'hershor01',
#   249: 'honeyri01',
#   250: 'johnsja01',
#   251: 'landrke01',
#   252: 'maldoca01',
#   253: 'marshmi02',
#   254: 'niedeto01',
#   255: 'oliveal01',
#   256: 'penaal01',
#   257: 'reussje01',
#   258: 'russebi01',
#   259: 'saxst01',
#   260: 'sciosmi01',
#   261: 'valenfe01',
#   262: 'welchbo01',
#   263: 'whitfte01',
#   264: 'yeagest01',
#   265: 'anderal02',
#   266: 'brunato01',
#   267: 'bushra01',
#   268: 'butchjo01',
#   269: 'castijo01',
#   270: 'davisro02',
#   271: 'engleda01',
#   272: 'filsope01',
#   273: 'gaettga01',
#   274: 'hatchmi01',
#   275: 'hrbekke01',
#   276: 'laudnti01',
#   277: 'puckeki01',
#   278: 'salasma01',
#   279: 'schroke01',
#   280: 'smallro02',
#   281: 'smithmi03',
#   282: 'teufeti01',
#   283: 'violafr01',
#   284: 'burrira01',
#   285: 'coopece01',
#   286: 'darwida01',
#   287: 'fingero01',
#   288: 'gantnji01',
#   289: 'haasmo01',
#   290: 'higuete01',
#   291: 'housepa02',
#   292: 'manniri01',
#   293: 'mcclubo01',
#   294: 'molitpa01',
#   295: 'moorech02',
#   296: 'oglivbe01',
#   297: 'romered01',
#   298: 'schrobi01',
#   299: 'simmote01',
#   300: 'vuckope01',
#   301: 'waitsri01',
#   302: 'yountro01',
#   303: 'brookhu01',
#   304: 'dawsoan01',
#   305: 'dilonmi01',
#   306: 'fishebr01',
#   307: 'flynndo01',
#   308: 'francte01',
#   309: 'gullibi01',
#   310: 'lawva01',
#   311: 'leach01',
#   312: 'lucasga01',
#   313: 'nicosst01',
#   314: 'palmeda01',
#   315: 'raineti01',
#   316: 'reardje01',
#   317: 'roberbe01',
#   318: 'schatda01',
#   319: 'smithbr01',
#   320: 'wallati01',
#   321: 'washiul01',
#   322: 'wohlfji01',
#   323: 'baylodo01',
#   324: 'berrada01',
#   325: 'bystrma01',
#   326: 'cowlejo01',
#   327: 'griffke01',
#   328: 'guidrro01',
#   329: 'hassero01',
#   330: 'henderi01',
#   331: 'kempst01',
#   332: 'mattido01',
#   333: 'meachbo01',
#   334: 'montejo01',
#   335: 'niekrph01',
#   336: 'randowi01',
#   337: 'righeda01',
#   338: 'samplbi01',
#   339: 'shirlbo01',
#   340: 'whitsed01',
#   341: 'winfida01',
#   342: 'wynegbu01',
#   343: 'backmwa01',
#   344: 'berenbr01',
#   345: 'bowala01',
#   346: 'cartega01',
#   347: 'darliro01',
#   348: 'fostege01',
#   349: 'gardero01',
#   350: 'goodedw01',
#   351: 'gormato03',
#   352: 'heepda01',
#   353: 'hernake01',
#   354: 'johnsho01',
#   355: 'knighra01',
#   356: 'lynched01',
#   357: 'mcdowro01',
#   358: 'oroscje01',
#   359: 'santara01',
#   360: 'siskdo01',
#   361: 'staubru01',
#   362: 'strawda01',
#   363: 'wilsomo01',
#   364: 'atherke01',
#   365: 'bakerdu01',
#   366: 'birtsti01',
#   367: 'bochtbr01',
#   368: 'codirch01',
#   369: 'collida02',
#   370: 'davismi02',
#   371: 'griffal01',
#   372: 'heathmi02',
#   373: 'hendest01',
#   374: 'howelja01',
#   375: 'johnto01',
#   376: 'kingmda01',
#   377: 'langfri01',
#   378: 'lansfca01',
#   379: 'mccatst01',
#   380: 'murphdw01',
#   381: 'norrimi01',
#   382: 'phillto02',
#   383: 'picciro01',
#   384: 'tellmto01',
#   385: 'aguaylu01',
#   386: 'anderla02',
#   387: 'carltst01',
#   388: 'corcoti01',
#   389: 'dennyjo01',
#   390: 'diazbo01',
#   391: 'grossgr01',
#   392: 'grosske01',
#   393: 'hayesvo01',
#   394: 'hudsoch02',
#   395: 'kniceal01',
#   396: 'koosmje01',
#   397: 'lefebjo01',
#   398: 'maddoga01',
#   399: 'rawlesh01',
#   400: 'ruckeda01',
#   401: 'samueju01',
#   402: 'schmimi01',
#   403: 'virgioz02',
#   404: 'almonbi01',
#   405: 'deleojo01',
#   406: 'guantce01',
#   407: 'hasslan01',
#   408: 'lezcasi01',
#   409: 'madlobi01',
#   410: 'mazzile01',
#   411: 'mcwilla01',
#   412: 'morriji01',
#   413: 'orsuljo01',
#   414: 'penato01',
#   415: 'rayjo01',
#   416: 'reuscri01',
#   417: 'rhoderi01',
#   418: 'robindo01',
#   419: 'scurrro01',
#   420: 'tekulke01',
#   421: 'thompja01',
#   422: 'tunnele01',
#   423: 'bevacku01',
#   424: 'brownbo04',
#   425: 'bumbral01',
#   426: 'draveda01',
#   427: 'flannti01',
#   428: 'garvest01',
#   429: 'gossari01',
#   430: 'gwynnto01',
#   431: 'hawkian01',
#   432: 'hoytla01',
#   433: 'jacksro03',
#   434: 'kennete02',
#   435: 'leffecr01',
#   436: 'martica01',
#   437: 'mcreyke01',
#   438: 'nettlgr01',
#   439: 'roystje01',
#   440: 'shower01',
#   441: 'stoddti01',
#   442: 'templga01',
#   443: 'thurmma01',
#   444: 'wiggial01',
#   445: 'beattji01',
#   446: 'bonneba01',
#   447: 'bradlph01',
#   448: 'cowenal01',
#   449: 'davisal01',
#   450: 'hendeda01',
#   451: 'kearnbo01',
#   452: 'langsma01',
#   453: 'mooremi01',
#   454: 'nunezed01',
#   455: 'owensp01',
#   456: 'percoja01',
#   457: 'phelpke01',
#   458: 'preslji01',
#   459: 'thomago01',
#   460: 'vandeed01',
#   461: 'youngma01',
#   462: 'ziskri01',
#   463: 'bluevi01',
#   464: 'brenlbo01',
#   465: 'brownch02',
#   466: 'davisch01',
#   467: 'davisma01',
#   468: 'driesda01',
#   469: 'garresc01',
#   470: 'gladdda01',
#   471: 'gottji01',
#   472: 'greenda03',
#   473: 'hammaat01',
#   474: 'krukomi01',
#   475: 'laskebi01',
#   476: 'lemasjo01',
#   477: 'leonaje01',
#   478: 'mintogr01',
#   479: 'thompsc01',
#   480: 'trevial01',
#   481: 'trillma01',
#   482: 'youngjo02',
#   483: 'allenne01',
#   484: 'andujjo01',
#   485: 'braunst01',
#   486: 'campbbi02',
#   487: 'cedence01',
#   488: 'clarkja01',
#   489: 'colemvi01',
#   490: 'coxda01',
#   491: 'dayleke01',
#   492: 'dejesiv01',
#   493: 'forscbo01',
#   494: 'harpebr01',
#   495: 'herrto01',
#   496: 'hortori01',
#   497: 'jorgemi01',
#   498: 'kepshku01',
#   499: 'lahtije01',
#   500: 'landrti01',
#   501: 'mcgeewi01',
#   502: 'pendlte01',
#   503: 'porteda02',
#   504: 'smithlo01',
#   505: 'smithoz01',
#   506: 'tudorjo01',
#   507: 'vanslan01',
#   508: 'bannial01',
#   509: 'harrato01',
#   510: 'hootobu01',
#   511: 'houghch01',
#   512: 'johnscl01',
#   513: 'jonesbo02',
#   514: 'mcdowod01',
#   515: 'nolesdi01',
#   516: 'obriepe03',
#   517: 'parrila01',
#   518: 'rozemda01',
#   519: 'schmida01',
#   520: 'slaugdo01',
#   521: 'steinbi02',
#   522: 'stewada01',
#   523: 'tananfr01',
#   524: 'tollewa01',
#   525: 'walkedu01',
#   526: 'wardga01',
#   527: 'wrighge03',
#   528: 'ackerji01',
#   529: 'alexado01',
#   530: 'barfije01',
#   531: 'bellge02',
#   532: 'burroje01',
#   533: 'caudibi01',
#   534: 'clancji01',
#   535: 'fernato01',
#   536: 'garcida01',
#   537: 'henketo01',
#   538: 'iorgga01',
#   539: 'keyji01',
#   540: 'lavelga01',
#   541: 'martibu01',
#   542: 'matusle01',
#   543: 'mosebll01',
#   544: 'mullira01',
#   545: 'stiebda01',
#   546: 'upshawi01',
#   547: 'whitter01',
#   548: 'ackerji01',
#   549: 'assenpa01',
#   550: 'barkele01',
#   551: 'benedbr01',
#   552: 'campri01',
#   553: 'chambch01',
#   554: 'dedmoje01',
#   555: 'garbege01',
#   556: 'harpete01',
#   557: 'hornebo01',
#   558: 'hubbagl01',
#   559: 'johnsjo05',
#   560: 'mahleri01',
#   561: 'mcmurcr01',
#   562: 'morenom01',
#   563: 'motleda01',
#   564: 'murphda05',
#   565: 'oberkke01',
#   566: 'olwined01',
#   567: 'palmeda01',
#   568: 'ramirra01',
#   569: 'samplbi01',
#   570: 'simmote01',
#   571: 'smithza01',
#   572: 'speckcl01',
#   573: 'suttebr01',
#   574: 'thomaan01',
#   575: 'virgioz02',
#   576: 'washicl01',
#   577: 'aasedo01',
#   578: 'beniqju01',
#   579: 'boddimi01',
#   580: 'bonilju01',
#   581: 'bordiri01',
#   582: 'davisst02',
#   583: 'dempsri01',
#   584: 'dixonke01',
#   585: 'dwyerji01',
#   586: 'flanami01',
#   587: 'fordda01',
#   588: 'grosswa01',
#   589: 'gutieja01',
#   590: 'havenbr01',
#   591: 'jonesod01',
#   592: 'lacyle01',
#   593: 'lynnfr01',
#   594: 'martide01',
#   595: 'martiti01',
#   596: 'mcgresc01',
#   597: 'murraed02',
#   598: 'nichore01',
#   599: 'rayfofl01',
#   600: 'ripkeca01',
#   601: 'sheetla01',
#   602: 'shelbjo01',
#   603: 'stefejo01',
#   604: 'trabeji01',
#   605: 'youngmi01',
#   606: 'armasto01',
#   607: 'barrema02',
#   608: 'baylodo01',
#   609: 'boggswa01',
#   610: 'boydoi01',
#   611: 'brownmi01',
#   612: 'bucknbi01',
#   613: 'clemero02',
#   614: 'crawfst01',
#   615: 'evansdw01',
#   616: 'gardnwe01',
#   617: 'gedmari01',
#   618: 'greenmi01',
#   619: 'hendeda01',
#   620: 'hoffmgl01',
#   621: 'hurstbr01',
#   622: 'lollati01',
#   623: 'nippeal01',
#   624: 'owensp01',
#   625: 'quinore01',
#   626: 'riceji01',
#   627: 'romered01',
#   628: 'sambijo01',
#   629: 'schirca01',
#   630: 'stanlbo01',
#   631: 'staplda01',
#   632: 'stewasa01',
#   633: 'sullima02',
#   634: 'trujimi01',
#   635: 'boonebo01',
#   636: 'burleri01',
#   637: 'candejo01',
#   638: 'corbedo01',
#   639: 'decindo01',
#   640: 'downibr01',
#   641: 'finlech01',
#   642: 'forscke01',
#   643: 'forstte01',
#   644: 'grichbo01',
#   645: 'hendrge01',
#   646: 'howelja02',
#   647: 'jacksre01',
#   648: 'johnto01',
#   649: 'jonesru01',
#   650: 'joynewa01',
#   651: 'lucasga01',
#   652: 'mccaski01',
#   653: 'mooredo01',
#   654: 'narroje01',
#   655: 'pettiga01',
#   656: 'romanro01',
#   657: 'ruhleve01',
#   658: 'schofdi02',
#   659: 'slatoji01',
#   660: 'suttodo01',
#   661: 'whitede03',
#   662: 'wilforo01',
#   663: 'wittmi01',
#   664: 'allenne01',
#   665: 'baineha01',
#   666: 'bannifl01',
#   667: 'bonilbo01',
#   668: 'bostoda01',
#   669: 'bradlsc01',
#   670: 'cangejo01',
#   671: 'carltst01',
#   672: 'cowlejo01',
#   673: 'cruzju01',
#   674: 'dotsori01',
#   675: 'fiskca01',
#   676: 'fostege01',
#   677: 'gilesbr01',
#   678: 'guilloz01',
#   679: 'hairsje01',
#   680: 'hillma01',
#   681: 'huletti01',
#   682: 'jamesbo01',
#   683: 'karkoro01',
#   684: 'kittlro01',
#   685: 'mckeojo01',
#   686: 'mormaru01',
#   687: 'nelsoge01',
#   688: 'percoja01',
#   689: 'schmida01',
#   690: 'seaveto01',
#   691: 'skinnjo01',
#   692: 'squirmi01',
#   693: 'thigpbo01',
#   694: 'walkegr01',
#   695: 'bosleth01',
#   696: 'brusswa01',
#   697: 'ceyro01',
#   698: 'davisjo02',
#   699: 'dernibo01',
#   700: 'dunstsh01',
#   701: 'durhale01',
#   702: 'eckerde01',
#   703: 'fontera01',
#   704: 'francte01',
#   705: 'frazige01',
#   706: 'gumpeda01',
#   707: 'hebneri01',
#   708: 'keougma02',
#   709: 'lakest01',
#   710: 'lopesda01',
#   711: 'martimi01',
#   712: 'matthga01',
#   713: 'morelke01',
#   714: 'moyerja01',
#   715: 'mumphje01',
#   716: 'ruthvdi01',
#   717: 'salazlu01',
#   718: 'sandbry01',
#   719: 'sandesc01',
#   720: 'smithle02',
#   721: 'speiech01',
#   722: 'sutclri01',
#   723: 'trillma01',
#   724: 'troutst01',
#   725: 'woodsga01',
#   726: 'bellbu01',
#   727: 'brownto05',
#   728: 'butersa01',
#   729: 'conceda01',
#   730: 'danieka01',
#   731: 'daviser01',
#   732: 'dennyjo01',
#   733: 'diazbo01',
#   734: 'esaskni01',
#   735: 'francjo01',
#   736: 'gullibi01',
#   737: 'jonestr01',
#   738: 'landrbi01',
#   739: 'larkiba01',
#   740: 'milneed01',
#   741: 'murphro01',
#   742: 'oestero01',
#   743: 'parkeda01',
#   744: 'pastofr01',
#   745: 'perezto01',
#   746: 'powerte01',
#   747: 'pricejo02',
#   748: 'robinro01',
#   749: 'rosepe01',
#   750: 'sotoma01',
#   751: 'stillku01',
#   752: 'vangoda01',
#   753: 'venabma01',
#   754: 'welshch01',
#   755: 'willica01',
#   756: 'allanan01',
#   757: 'bailesc01',
#   758: 'bandoch01',
#   759: 'bernato01',
#   760: 'butlebr01',
#   761: 'camacer01',
#   762: 'candito01',
#   763: 'cartejo01',
#   764: 'castica01',
#   765: 'easteja01',
#   766: 'francju01',
#   767: 'garlawa01',
#   768: 'hallme01',
#   769: 'heatone01',
#   770: 'jacobbr01',
#   771: 'kernji01',
#   772: 'mullifr01',
#   773: 'niekrph01',
#   774: 'nixonot01',
#   775: 'nolesdi01',
#   776: 'oelkebr01',
#   777: 'romanjo02',
#   778: 'schroke01',
#   779: 'schuldo01',
#   780: 'snydeco02',
#   781: 'swindgr01',
#   782: 'tablepa01',
#   783: 'thornan01',
#   784: 'waddeto01',
#   785: 'willsfr01',
#   786: 'yettri01',
#   787: 'bergmda01',
#   788: 'brookto01',
#   789: 'campbbi02',
#   790: 'colesda01',
#   791: 'collida02',
#   792: 'evansda01',
#   793: 'gibsoki01',
#   794: 'grubbjo01',
#   795: 'hernawi01',
#   796: 'herndla01',
#   797: 'kinger01',
#   798: 'lagami01',
#   799: 'lapoida01',
#   800: 'lemonch01',
#   801: 'lowrydw01',
#   802: 'morrija02',
#   803: 'onealra01',
#   804: 'parrila02',
#   805: 'petryda01',
#   806: 'sheripa01',
#   807: 'slatoji01',
#   808: 'spilmha01',
#   809: 'tananfr01',
#   810: 'terrewa01',
#   811: 'tollewa01',
#   812: 'trammal01',
#   813: 'whitalo01',
#   814: 'anderla02',
#   815: 'ashbyal01',
#   816: 'basske01',
#   817: 'calhoje01',
#   818: 'cruzjo01',
#   819: 'davisgl01',
#   820: 'dawlebi01',
#   821: 'deshaji01',
#   822: 'dipinfr01',
#   823: 'doranbi02',
#   824: 'garneph01',
#   825: 'hatchbi01',
#   826: 'kerfech01',
#   827: 'kneppbo01',
#   828: 'lopezau01',
#   829: 'mizerjo01',
#   830: 'pankoji01',
#   831: 'puhlte01',
#   832: 'reynocr01',
#   833: 'ryanno01',
#   834: 'scottmi03',
#   835: 'smithda02',
#   836: 'thondi01',
#   837: 'wallide01',
#   838: 'balbost01',
#   839: 'bankhsc01',
#   840: 'biancbu01',
#   841: 'blackbu02',
#   842: 'brettge01',
#   843: 'coneda01',
#   844: 'farrst01',
#   845: 'gubicma01',
#   846: 'hargeal01',
#   847: 'huismma01',
#   848: 'jacksda02',
#   849: 'jonesly01',
#   850: 'kingemi01',
#   851: 'lawru01',
#   852: 'leibrch01',
#   853: 'leonade01',
#   854: 'mcraeha01',
#   855: 'ortajo01',
#   856: 'pryorgr01',
#   857: 'quirkja01',
#   858: 'quiseda01',
#   859: 'saberbr01',
#   860: 'salazan01',
#   861: 'smithlo01',
#   862: 'sundbji01',
#   863: 'wathajo01',
#   864: 'whitefr01',
#   865: 'wilsowi02',
#   866: 'anderda02',
#   867: 'bailobo01',
#   868: 'beckwjo01',
#   869: 'brockgr01',
#   870: 'cabelen01',
#   871: 'cedence01',
#   872: 'duncama01',
#   873: 'gonzajo02',
#   874: 'guerrpe01',
#   875: 'hamilje01',
#   876: 'hershor01',
#   877: 'holtobr01',
#   878: 'honeyri01',
#   879: 'howelke01',
#   880: 'landrke01',
#   881: 'madlobi01',
#   882: 'marshmi02',
#   883: 'matusle01',
#   884: 'niedeto01',
#   885: 'penaal01',
#   886: 'powelde01',
#   887: 'reussje01',
#   888: 'russebi01',
#   889: 'saxst01',
#   890: 'sciosmi01',
#   891: 'stubbfr01',
#   892: 'trevial01',
#   893: 'valenfe01',
#   894: 'vandeed01',
#   895: 'vonohda01',
#   896: 'welchbo01',
#   897: 'willire01',
#   898: 'beanebi01',
#   899: 'blylebe01',
#   900: 'brunato01',
#   901: 'bushra01',
#   902: 'butchjo01',
#   903: 'davisro02',
#   904: 'espinal01',
#   905: 'gaettga01',
#   906: 'gagnegr01',
#   907: 'hatchmi01',
#   908: 'hrbekke01',
#   909: 'jacksro03',
#   910: 'laudnti01',
#   911: 'lombast01',
#   912: 'pastofr01',
#   913: 'portuma01',
#   914: 'puckeki01',
#   915: 'reedje02',
#   916: 'salasma01',
#   917: 'smallro02',
#   918: 'smithmi03',
#   919: 'violafr01',
#   920: 'birkbmi01',
#   921: 'bosioch01',
#   922: 'bragggl01',
#   923: 'ceronri01',
#   924: 'clearma01',
#   925: 'cluttbr01',
#   926: 'coopece01',
#   927: 'darwida01',
#   928: 'deerro01',
#   929: 'gantnji01',
#   930: 'haasmo01',
#   931: 'higuete01',
#   932: 'johnsjo04',
#   933: 'learyti01',
#   934: 'manniri01',
#   935: 'mcclubo01',
#   936: 'molitpa01',
#   937: 'moorech02',
#   938: 'nieveju01',
#   939: 'oglivbe01',
#   940: 'plesada01',
#   941: 'rileser01',
#   942: 'schrobi01',
#   943: 'searara01',
#   944: 'sveumda01',
#   945: 'thomago01',
#   946: 'wegmabi01',
#   947: 'yountro01',
#   948: 'bilarda01',
#   949: 'brookhu01',
#   950: 'burketi01',
#   951: 'dawsoan01',
#   952: 'fitzgmi02',
#   953: 'flynndo01',
#   954: 'galaran01',
#   955: 'heskejo01',
#   956: 'huntra01',
#   957: 'johnswa03',
#   958: 'krencwa01',
#   959: 'lawva01',
#   960: 'leach01',
#   961: 'mcgafan01',
#   962: 'newmaal01',
#   963: 'nietoto01',
#   964: 'raineti01',
#   965: 'reardje01',
#   966: 'riverlu01',
#   967: 'roberbe01',
#   968: 'schatda01',
#   969: 'sebrabo01',
#   970: 'smithbr01',
#   971: 'thompja01',
#   972: 'thompsc01',
#   973: 'tibbsja01',
#   974: 'tomlida01',
#   975: 'wallati01',
#   976: 'webstmi01',
#   977: 'winnihe01',
#   978: 'wohlfji01',
#   979: 'youmafl01',
#   980: 'berrada01',
#   981: 'burnsbr01',
#   982: 'drabedo01',
#   983: 'easlemi01',
#   984: 'espinju01',
#   985: 'fischmi01',
#   986: 'fishebr01',
#   987: 'griffke01',
#   988: 'guidrro01',
#   989: 'hassero01',
#   990: 'henderi01',
#   991: 'johnto01',
#   992: 'kempst01',
#   993: 'mattido01',
#   994: 'montejo01',
#   995: 'morenom01',
#   996: 'niekrjo01',
#   997: 'paglimi01',
#   998: 'pasquda01',
#   999: 'randowi01',
#   ...},
#  '1985': {0: 1985,
#   1: 1985,
#   2: 1985,
#   3: 1985,
#   4: 1985,
#   5: 1985,
#   6: 1985,
#   7: 1985,
#   8: 1985,
#   9: 1985,
#   10: 1985,
#   11: 1985,
#   12: 1985,
#   13: 1985,
#   14: 1985,
#   15: 1985,
#   16: 1985,
#   17: 1985,
#   18: 1985,
#   19: 1985,
#   20: 1985,
#   21: 1985,
#   22: 1985,
#   23: 1985,
#   24: 1985,
#   25: 1985,
#   26: 1985,
#   27: 1985,
#   28: 1985,
#   29: 1985,
#   30: 1985,
#   31: 1985,
#   32: 1985,
#   33: 1985,
#   34: 1985,
#   35: 1985,
#   36: 1985,
#   37: 1985,
#   38: 1985,
#   39: 1985,
#   40: 1985,
#   41: 1985,
#   42: 1985,
#   43: 1985,
#   44: 1985,
#   45: 1985,
#   46: 1985,
#   47: 1985,
#   48: 1985,
#   49: 1985,
#   50: 1985,
#   51: 1985,
#   52: 1985,
#   53: 1985,
#   54: 1985,
#   55: 1985,
#   56: 1985,
#   57: 1985,
#   58: 1985,
#   59: 1985,
#   60: 1985,
#   61: 1985,
#   62: 1985,
#   63: 1985,
#   64: 1985,
#   65: 1985,
#   66: 1985,
#   67: 1985,
#   68: 1985,
#   69: 1985,
#   70: 1985,
#   71: 1985,
#   72: 1985,
#   73: 1985,
#   74: 1985,
#   75: 1985,
#   76: 1985,
#   77: 1985,
#   78: 1985,
#   79: 1985,
#   80: 1985,
#   81: 1985,
#   82: 1985,
#   83: 1985,
#   84: 1985,
#   85: 1985,
#   86: 1985,
#   87: 1985,
#   88: 1985,
#   89: 1985,
#   90: 1985,
#   91: 1985,
#   92: 1985,
#   93: 1985,
#   94: 1985,
#   95: 1985,
#   96: 1985,
#   97: 1985,
#   98: 1985,
#   99: 1985,
#   100: 1985,
#   101: 1985,
#   102: 1985,
#   103: 1985,
#   104: 1985,
#   105: 1985,
#   106: 1985,
#   107: 1985,
#   108: 1985,
#   109: 1985,
#   110: 1985,
#   111: 1985,
#   112: 1985,
#   113: 1985,
#   114: 1985,
#   115: 1985,
#   116: 1985,
#   117: 1985,
#   118: 1985,
#   119: 1985,
#   120: 1985,
#   121: 1985,
#   122: 1985,
#   123: 1985,
#   124: 1985,
#   125: 1985,
#   126: 1985,
#   127: 1985,
#   128: 1985,
#   129: 1985,
#   130: 1985,
#   131: 1985,
#   132: 1985,
#   133: 1985,
#   134: 1985,
#   135: 1985,
#   136: 1985,
#   137: 1985,
#   138: 1985,
#   139: 1985,
#   140: 1985,
#   141: 1985,
#   142: 1985,
#   143: 1985,
#   144: 1985,
#   145: 1985,
#   146: 1985,
#   147: 1985,
#   148: 1985,
#   149: 1985,
#   150: 1985,
#   151: 1985,
#   152: 1985,
#   153: 1985,
#   154: 1985,
#   155: 1985,
#   156: 1985,
#   157: 1985,
#   158: 1985,
#   159: 1985,
#   160: 1985,
#   161: 1985,
#   162: 1985,
#   163: 1985,
#   164: 1985,
#   165: 1985,
#   166: 1985,
#   167: 1985,
#   168: 1985,
#   169: 1985,
#   170: 1985,
#   171: 1985,
#   172: 1985,
#   173: 1985,
#   174: 1985,
#   175: 1985,
#   176: 1985,
#   177: 1985,
#   178: 1985,
#   179: 1985,
#   180: 1985,
#   181: 1985,
#   182: 1985,
#   183: 1985,
#   184: 1985,
#   185: 1985,
#   186: 1985,
#   187: 1985,
#   188: 1985,
#   189: 1985,
#   190: 1985,
#   191: 1985,
#   192: 1985,
#   193: 1985,
#   194: 1985,
#   195: 1985,
#   196: 1985,
#   197: 1985,
#   198: 1985,
#   199: 1985,
#   200: 1985,
#   201: 1985,
#   202: 1985,
#   203: 1985,
#   204: 1985,
#   205: 1985,
#   206: 1985,
#   207: 1985,
#   208: 1985,
#   209: 1985,
#   210: 1985,
#   211: 1985,
#   212: 1985,
#   213: 1985,
#   214: 1985,
#   215: 1985,
#   216: 1985,
#   217: 1985,
#   218: 1985,
#   219: 1985,
#   220: 1985,
#   221: 1985,
#   222: 1985,
#   223: 1985,
#   224: 1985,
#   225: 1985,
#   226: 1985,
#   227: 1985,
#   228: 1985,
#   229: 1985,
#   230: 1985,
#   231: 1985,
#   232: 1985,
#   233: 1985,
#   234: 1985,
#   235: 1985,
#   236: 1985,
#   237: 1985,
#   238: 1985,
#   239: 1985,
#   240: 1985,
#   241: 1985,
#   242: 1985,
#   243: 1985,
#   244: 1985,
#   245: 1985,
#   246: 1985,
#   247: 1985,
#   248: 1985,
#   249: 1985,
#   250: 1985,
#   251: 1985,
#   252: 1985,
#   253: 1985,
#   254: 1985,
#   255: 1985,
#   256: 1985,
#   257: 1985,
#   258: 1985,
#   259: 1985,
#   260: 1985,
#   261: 1985,
#   262: 1985,
#   263: 1985,
#   264: 1985,
#   265: 1985,
#   266: 1985,
#   267: 1985,
#   268: 1985,
#   269: 1985,
#   270: 1985,
#   271: 1985,
#   272: 1985,
#   273: 1985,
#   274: 1985,
#   275: 1985,
#   276: 1985,
#   277: 1985,
#   278: 1985,
#   279: 1985,
#   280: 1985,
#   281: 1985,
#   282: 1985,
#   283: 1985,
#   284: 1985,
#   285: 1985,
#   286: 1985,
#   287: 1985,
#   288: 1985,
#   289: 1985,
#   290: 1985,
#   291: 1985,
#   292: 1985,
#   293: 1985,
#   294: 1985,
#   295: 1985,
#   296: 1985,
#   297: 1985,
#   298: 1985,
#   299: 1985,
#   300: 1985,
#   301: 1985,
#   302: 1985,
#   303: 1985,
#   304: 1985,
#   305: 1985,
#   306: 1985,
#   307: 1985,
#   308: 1985,
#   309: 1985,
#   310: 1985,
#   311: 1985,
#   312: 1985,
#   313: 1985,
#   314: 1985,
#   315: 1985,
#   316: 1985,
#   317: 1985,
#   318: 1985,
#   319: 1985,
#   320: 1985,
#   321: 1985,
#   322: 1985,
#   323: 1985,
#   324: 1985,
#   325: 1985,
#   326: 1985,
#   327: 1985,
#   328: 1985,
#   329: 1985,
#   330: 1985,
#   331: 1985,
#   332: 1985,
#   333: 1985,
#   334: 1985,
#   335: 1985,
#   336: 1985,
#   337: 1985,
#   338: 1985,
#   339: 1985,
#   340: 1985,
#   341: 1985,
#   342: 1985,
#   343: 1985,
#   344: 1985,
#   345: 1985,
#   346: 1985,
#   347: 1985,
#   348: 1985,
#   349: 1985,
#   350: 1985,
#   351: 1985,
#   352: 1985,
#   353: 1985,
#   354: 1985,
#   355: 1985,
#   356: 1985,
#   357: 1985,
#   358: 1985,
#   359: 1985,
#   360: 1985,
#   361: 1985,
#   362: 1985,
#   363: 1985,
#   364: 1985,
#   365: 1985,
#   366: 1985,
#   367: 1985,
#   368: 1985,
#   369: 1985,
#   370: 1985,
#   371: 1985,
#   372: 1985,
#   373: 1985,
#   374: 1985,
#   375: 1985,
#   376: 1985,
#   377: 1985,
#   378: 1985,
#   379: 1985,
#   380: 1985,
#   381: 1985,
#   382: 1985,
#   383: 1985,
#   384: 1985,
#   385: 1985,
#   386: 1985,
#   387: 1985,
#   388: 1985,
#   389: 1985,
#   390: 1985,
#   391: 1985,
#   392: 1985,
#   393: 1985,
#   394: 1985,
#   395: 1985,
#   396: 1985,
#   397: 1985,
#   398: 1985,
#   399: 1985,
#   400: 1985,
#   401: 1985,
#   402: 1985,
#   403: 1985,
#   404: 1985,
#   405: 1985,
#   406: 1985,
#   407: 1985,
#   408: 1985,
#   409: 1985,
#   410: 1985,
#   411: 1985,
#   412: 1985,
#   413: 1985,
#   414: 1985,
#   415: 1985,
#   416: 1985,
#   417: 1985,
#   418: 1985,
#   419: 1985,
#   420: 1985,
#   421: 1985,
#   422: 1985,
#   423: 1985,
#   424: 1985,
#   425: 1985,
#   426: 1985,
#   427: 1985,
#   428: 1985,
#   429: 1985,
#   430: 1985,
#   431: 1985,
#   432: 1985,
#   433: 1985,
#   434: 1985,
#   435: 1985,
#   436: 1985,
#   437: 1985,
#   438: 1985,
#   439: 1985,
#   440: 1985,
#   441: 1985,
#   442: 1985,
#   443: 1985,
#   444: 1985,
#   445: 1985,
#   446: 1985,
#   447: 1985,
#   448: 1985,
#   449: 1985,
#   450: 1985,
#   451: 1985,
#   452: 1985,
#   453: 1985,
#   454: 1985,
#   455: 1985,
#   456: 1985,
#   457: 1985,
#   458: 1985,
#   459: 1985,
#   460: 1985,
#   461: 1985,
#   462: 1985,
#   463: 1985,
#   464: 1985,
#   465: 1985,
#   466: 1985,
#   467: 1985,
#   468: 1985,
#   469: 1985,
#   470: 1985,
#   471: 1985,
#   472: 1985,
#   473: 1985,
#   474: 1985,
#   475: 1985,
#   476: 1985,
#   477: 1985,
#   478: 1985,
#   479: 1985,
#   480: 1985,
#   481: 1985,
#   482: 1985,
#   483: 1985,
#   484: 1985,
#   485: 1985,
#   486: 1985,
#   487: 1985,
#   488: 1985,
#   489: 1985,
#   490: 1985,
#   491: 1985,
#   492: 1985,
#   493: 1985,
#   494: 1985,
#   495: 1985,
#   496: 1985,
#   497: 1985,
#   498: 1985,
#   499: 1985,
#   500: 1985,
#   501: 1985,
#   502: 1985,
#   503: 1985,
#   504: 1985,
#   505: 1985,
#   506: 1985,
#   507: 1985,
#   508: 1985,
#   509: 1985,
#   510: 1985,
#   511: 1985,
#   512: 1985,
#   513: 1985,
#   514: 1985,
#   515: 1985,
#   516: 1985,
#   517: 1985,
#   518: 1985,
#   519: 1985,
#   520: 1985,
#   521: 1985,
#   522: 1985,
#   523: 1985,
#   524: 1985,
#   525: 1985,
#   526: 1985,
#   527: 1985,
#   528: 1985,
#   529: 1985,
#   530: 1985,
#   531: 1985,
#   532: 1985,
#   533: 1985,
#   534: 1985,
#   535: 1985,
#   536: 1985,
#   537: 1985,
#   538: 1985,
#   539: 1985,
#   540: 1985,
#   541: 1985,
#   542: 1985,
#   543: 1985,
#   544: 1985,
#   545: 1985,
#   546: 1985,
#   547: 1985,
#   548: 1986,
#   549: 1986,
#   550: 1986,
#   551: 1986,
#   552: 1986,
#   553: 1986,
#   554: 1986,
#   555: 1986,
#   556: 1986,
#   557: 1986,
#   558: 1986,
#   559: 1986,
#   560: 1986,
#   561: 1986,
#   562: 1986,
#   563: 1986,
#   564: 1986,
#   565: 1986,
#   566: 1986,
#   567: 1986,
#   568: 1986,
#   569: 1986,
#   570: 1986,
#   571: 1986,
#   572: 1986,
#   573: 1986,
#   574: 1986,
#   575: 1986,
#   576: 1986,
#   577: 1986,
#   578: 1986,
#   579: 1986,
#   580: 1986,
#   581: 1986,
#   582: 1986,
#   583: 1986,
#   584: 1986,
#   585: 1986,
#   586: 1986,
#   587: 1986,
#   588: 1986,
#   589: 1986,
#   590: 1986,
#   591: 1986,
#   592: 1986,
#   593: 1986,
#   594: 1986,
#   595: 1986,
#   596: 1986,
#   597: 1986,
#   598: 1986,
#   599: 1986,
#   600: 1986,
#   601: 1986,
#   602: 1986,
#   603: 1986,
#   604: 1986,
#   605: 1986,
#   606: 1986,
#   607: 1986,
#   608: 1986,
#   609: 1986,
#   610: 1986,
#   611: 1986,
#   612: 1986,
#   613: 1986,
#   614: 1986,
#   615: 1986,
#   616: 1986,
#   617: 1986,
#   618: 1986,
#   619: 1986,
#   620: 1986,
#   621: 1986,
#   622: 1986,
#   623: 1986,
#   624: 1986,
#   625: 1986,
#   626: 1986,
#   627: 1986,
#   628: 1986,
#   629: 1986,
#   630: 1986,
#   631: 1986,
#   632: 1986,
#   633: 1986,
#   634: 1986,
#   635: 1986,
#   636: 1986,
#   637: 1986,
#   638: 1986,
#   639: 1986,
#   640: 1986,
#   641: 1986,
#   642: 1986,
#   643: 1986,
#   644: 1986,
#   645: 1986,
#   646: 1986,
#   647: 1986,
#   648: 1986,
#   649: 1986,
#   650: 1986,
#   651: 1986,
#   652: 1986,
#   653: 1986,
#   654: 1986,
#   655: 1986,
#   656: 1986,
#   657: 1986,
#   658: 1986,
#   659: 1986,
#   660: 1986,
#   661: 1986,
#   662: 1986,
#   663: 1986,
#   664: 1986,
#   665: 1986,
#   666: 1986,
#   667: 1986,
#   668: 1986,
#   669: 1986,
#   670: 1986,
#   671: 1986,
#   672: 1986,
#   673: 1986,
#   674: 1986,
#   675: 1986,
#   676: 1986,
#   677: 1986,
#   678: 1986,
#   679: 1986,
#   680: 1986,
#   681: 1986,
#   682: 1986,
#   683: 1986,
#   684: 1986,
#   685: 1986,
#   686: 1986,
#   687: 1986,
#   688: 1986,
#   689: 1986,
#   690: 1986,
#   691: 1986,
#   692: 1986,
#   693: 1986,
#   694: 1986,
#   695: 1986,
#   696: 1986,
#   697: 1986,
#   698: 1986,
#   699: 1986,
#   700: 1986,
#   701: 1986,
#   702: 1986,
#   703: 1986,
#   704: 1986,
#   705: 1986,
#   706: 1986,
#   707: 1986,
#   708: 1986,
#   709: 1986,
#   710: 1986,
#   711: 1986,
#   712: 1986,
#   713: 1986,
#   714: 1986,
#   715: 1986,
#   716: 1986,
#   717: 1986,
#   718: 1986,
#   719: 1986,
#   720: 1986,
#   721: 1986,
#   722: 1986,
#   723: 1986,
#   724: 1986,
#   725: 1986,
#   726: 1986,
#   727: 1986,
#   728: 1986,
#   729: 1986,
#   730: 1986,
#   731: 1986,
#   732: 1986,
#   733: 1986,
#   734: 1986,
#   735: 1986,
#   736: 1986,
#   737: 1986,
#   738: 1986,
#   739: 1986,
#   740: 1986,
#   741: 1986,
#   742: 1986,
#   743: 1986,
#   744: 1986,
#   745: 1986,
#   746: 1986,
#   747: 1986,
#   748: 1986,
#   749: 1986,
#   750: 1986,
#   751: 1986,
#   752: 1986,
#   753: 1986,
#   754: 1986,
#   755: 1986,
#   756: 1986,
#   757: 1986,
#   758: 1986,
#   759: 1986,
#   760: 1986,
#   761: 1986,
#   762: 1986,
#   763: 1986,
#   764: 1986,
#   765: 1986,
#   766: 1986,
#   767: 1986,
#   768: 1986,
#   769: 1986,
#   770: 1986,
#   771: 1986,
#   772: 1986,
#   773: 1986,
#   774: 1986,
#   775: 1986,
#   776: 1986,
#   777: 1986,
#   778: 1986,
#   779: 1986,
#   780: 1986,
#   781: 1986,
#   782: 1986,
#   783: 1986,
#   784: 1986,
#   785: 1986,
#   786: 1986,
#   787: 1986,
#   788: 1986,
#   789: 1986,
#   790: 1986,
#   791: 1986,
#   792: 1986,
#   793: 1986,
#   794: 1986,
#   795: 1986,
#   796: 1986,
#   797: 1986,
#   798: 1986,
#   799: 1986,
#   800: 1986,
#   801: 1986,
#   802: 1986,
#   803: 1986,
#   804: 1986,
#   805: 1986,
#   806: 1986,
#   807: 1986,
#   808: 1986,
#   809: 1986,
#   810: 1986,
#   811: 1986,
#   812: 1986,
#   813: 1986,
#   814: 1986,
#   815: 1986,
#   816: 1986,
#   817: 1986,
#   818: 1986,
#   819: 1986,
#   820: 1986,
#   821: 1986,
#   822: 1986,
#   823: 1986,
#   824: 1986,
#   825: 1986,
#   826: 1986,
#   827: 1986,
#   828: 1986,
#   829: 1986,
#   830: 1986,
#   831: 1986,
#   832: 1986,
#   833: 1986,
#   834: 1986,
#   835: 1986,
#   836: 1986,
#   837: 1986,
#   838: 1986,
#   839: 1986,
#   840: 1986,
#   841: 1986,
#   842: 1986,
#   843: 1986,
#   844: 1986,
#   845: 1986,
#   846: 1986,
#   847: 1986,
#   848: 1986,
#   849: 1986,
#   850: 1986,
#   851: 1986,
#   852: 1986,
#   853: 1986,
#   854: 1986,
#   855: 1986,
#   856: 1986,
#   857: 1986,
#   858: 1986,
#   859: 1986,
#   860: 1986,
#   861: 1986,
#   862: 1986,
#   863: 1986,
#   864: 1986,
#   865: 1986,
#   866: 1986,
#   867: 1986,
#   868: 1986,
#   869: 1986,
#   870: 1986,
#   871: 1986,
#   872: 1986,
#   873: 1986,
#   874: 1986,
#   875: 1986,
#   876: 1986,
#   877: 1986,
#   878: 1986,
#   879: 1986,
#   880: 1986,
#   881: 1986,
#   882: 1986,
#   883: 1986,
#   884: 1986,
#   885: 1986,
#   886: 1986,
#   887: 1986,
#   888: 1986,
#   889: 1986,
#   890: 1986,
#   891: 1986,
#   892: 1986,
#   893: 1986,
#   894: 1986,
#   895: 1986,
#   896: 1986,
#   897: 1986,
#   898: 1986,
#   899: 1986,
#   900: 1986,
#   901: 1986,
#   902: 1986,
#   903: 1986,
#   904: 1986,
#   905: 1986,
#   906: 1986,
#   907: 1986,
#   908: 1986,
#   909: 1986,
#   910: 1986,
#   911: 1986,
#   912: 1986,
#   913: 1986,
#   914: 1986,
#   915: 1986,
#   916: 1986,
#   917: 1986,
#   918: 1986,
#   919: 1986,
#   920: 1986,
#   921: 1986,
#   922: 1986,
#   923: 1986,
#   924: 1986,
#   925: 1986,
#   926: 1986,
#   927: 1986,
#   928: 1986,
#   929: 1986,
#   930: 1986,
#   931: 1986,
#   932: 1986,
#   933: 1986,
#   934: 1986,
#   935: 1986,
#   936: 1986,
#   937: 1986,
#   938: 1986,
#   939: 1986,
#   940: 1986,
#   941: 1986,
#   942: 1986,
#   943: 1986,
#   944: 1986,
#   945: 1986,
#   946: 1986,
#   947: 1986,
#   948: 1986,
#   949: 1986,
#   950: 1986,
#   951: 1986,
#   952: 1986,
#   953: 1986,
#   954: 1986,
#   955: 1986,
#   956: 1986,
#   957: 1986,
#   958: 1986,
#   959: 1986,
#   960: 1986,
#   961: 1986,
#   962: 1986,
#   963: 1986,
#   964: 1986,
#   965: 1986,
#   966: 1986,
#   967: 1986,
#   968: 1986,
#   969: 1986,
#   970: 1986,
#   971: 1986,
#   972: 1986,
#   973: 1986,
#   974: 1986,
#   975: 1986,
#   976: 1986,
#   977: 1986,
#   978: 1986,
#   979: 1986,
#   980: 1986,
#   981: 1986,
#   982: 1986,
#   983: 1986,
#   984: 1986,
#   985: 1986,
#   986: 1986,
#   987: 1986,
#   988: 1986,
#   989: 1986,
#   990: 1986,
#   991: 1986,
#   992: 1986,
#   993: 1986,
#   994: 1986,
#   995: 1986,
#   996: 1986,
#   997: 1986,
#   998: 1986,
#   999: 1986,
#   ...},
#  'ATL': {0: 'ATL',
#   1: 'ATL',
#   2: 'ATL',
#   3: 'ATL',
#   4: 'ATL',
#   5: 'ATL',
#   6: 'ATL',
#   7: 'ATL',
#   8: 'ATL',
#   9: 'ATL',
#   10: 'ATL',
#   11: 'ATL',
#   12: 'ATL',
#   13: 'ATL',
#   14: 'ATL',
#   15: 'ATL',
#   16: 'ATL',
#   17: 'ATL',
#   18: 'ATL',
#   19: 'ATL',
#   20: 'BAL',
#   21: 'BAL',
#   22: 'BAL',
#   23: 'BAL',
#   24: 'BAL',
#   25: 'BAL',
#   26: 'BAL',
#   27: 'BAL',
#   28: 'BAL',
#   29: 'BAL',
#   30: 'BAL',
#   31: 'BAL',
#   32: 'BAL',
#   33: 'BAL',
#   34: 'BAL',
#   35: 'BAL',
#   36: 'BAL',
#   37: 'BAL',
#   38: 'BAL',
#   39: 'BAL',
#   40: 'BAL',
#   41: 'BAL',
#   42: 'BOS',
#   43: 'BOS',
#   44: 'BOS',
#   45: 'BOS',
#   46: 'BOS',
#   47: 'BOS',
#   48: 'BOS',
#   49: 'BOS',
#   50: 'BOS',
#   51: 'BOS',
#   52: 'BOS',
#   53: 'BOS',
#   54: 'BOS',
#   55: 'BOS',
#   56: 'BOS',
#   57: 'BOS',
#   58: 'BOS',
#   59: 'BOS',
#   60: 'BOS',
#   61: 'BOS',
#   62: 'BOS',
#   63: 'BOS',
#   64: 'BOS',
#   65: 'BOS',
#   66: 'BOS',
#   67: 'CAL',
#   68: 'CAL',
#   69: 'CAL',
#   70: 'CAL',
#   71: 'CAL',
#   72: 'CAL',
#   73: 'CAL',
#   74: 'CAL',
#   75: 'CAL',
#   76: 'CAL',
#   77: 'CAL',
#   78: 'CAL',
#   79: 'CAL',
#   80: 'CAL',
#   81: 'CAL',
#   82: 'CAL',
#   83: 'CAL',
#   84: 'CAL',
#   85: 'CAL',
#   86: 'CAL',
#   87: 'CAL',
#   88: 'CAL',
#   89: 'CAL',
#   90: 'CAL',
#   91: 'CAL',
#   92: 'CAL',
#   93: 'CAL',
#   94: 'CAL',
#   95: 'CHA',
#   96: 'CHA',
#   97: 'CHA',
#   98: 'CHA',
#   99: 'CHA',
#   100: 'CHA',
#   101: 'CHA',
#   102: 'CHA',
#   103: 'CHA',
#   104: 'CHA',
#   105: 'CHA',
#   106: 'CHA',
#   107: 'CHA',
#   108: 'CHA',
#   109: 'CHA',
#   110: 'CHA',
#   111: 'CHA',
#   112: 'CHA',
#   113: 'CHA',
#   114: 'CHA',
#   115: 'CHA',
#   116: 'CHN',
#   117: 'CHN',
#   118: 'CHN',
#   119: 'CHN',
#   120: 'CHN',
#   121: 'CHN',
#   122: 'CHN',
#   123: 'CHN',
#   124: 'CHN',
#   125: 'CHN',
#   126: 'CHN',
#   127: 'CHN',
#   128: 'CHN',
#   129: 'CHN',
#   130: 'CHN',
#   131: 'CHN',
#   132: 'CHN',
#   133: 'CHN',
#   134: 'CHN',
#   135: 'CHN',
#   136: 'CHN',
#   137: 'CHN',
#   138: 'CIN',
#   139: 'CIN',
#   140: 'CIN',
#   141: 'CIN',
#   142: 'CIN',
#   143: 'CIN',
#   144: 'CIN',
#   145: 'CIN',
#   146: 'CIN',
#   147: 'CIN',
#   148: 'CIN',
#   149: 'CIN',
#   150: 'CIN',
#   151: 'CIN',
#   152: 'CIN',
#   153: 'CIN',
#   154: 'CIN',
#   155: 'CIN',
#   156: 'CIN',
#   157: 'CIN',
#   158: 'CIN',
#   159: 'CIN',
#   160: 'CLE',
#   161: 'CLE',
#   162: 'CLE',
#   163: 'CLE',
#   164: 'CLE',
#   165: 'CLE',
#   166: 'CLE',
#   167: 'CLE',
#   168: 'CLE',
#   169: 'CLE',
#   170: 'CLE',
#   171: 'CLE',
#   172: 'CLE',
#   173: 'CLE',
#   174: 'CLE',
#   175: 'CLE',
#   176: 'CLE',
#   177: 'CLE',
#   178: 'CLE',
#   179: 'CLE',
#   180: 'DET',
#   181: 'DET',
#   182: 'DET',
#   183: 'DET',
#   184: 'DET',
#   185: 'DET',
#   186: 'DET',
#   187: 'DET',
#   188: 'DET',
#   189: 'DET',
#   190: 'DET',
#   191: 'DET',
#   192: 'DET',
#   193: 'DET',
#   194: 'DET',
#   195: 'DET',
#   196: 'DET',
#   197: 'DET',
#   198: 'DET',
#   199: 'DET',
#   200: 'HOU',
#   201: 'HOU',
#   202: 'HOU',
#   203: 'HOU',
#   204: 'HOU',
#   205: 'HOU',
#   206: 'HOU',
#   207: 'HOU',
#   208: 'HOU',
#   209: 'HOU',
#   210: 'HOU',
#   211: 'HOU',
#   212: 'HOU',
#   213: 'HOU',
#   214: 'HOU',
#   215: 'HOU',
#   216: 'HOU',
#   217: 'HOU',
#   218: 'HOU',
#   219: 'HOU',
#   220: 'KCA',
#   221: 'KCA',
#   222: 'KCA',
#   223: 'KCA',
#   224: 'KCA',
#   225: 'KCA',
#   226: 'KCA',
#   227: 'KCA',
#   228: 'KCA',
#   229: 'KCA',
#   230: 'KCA',
#   231: 'KCA',
#   232: 'KCA',
#   233: 'KCA',
#   234: 'KCA',
#   235: 'KCA',
#   236: 'KCA',
#   237: 'KCA',
#   238: 'KCA',
#   239: 'KCA',
#   240: 'KCA',
#   241: 'KCA',
#   242: 'LAN',
#   243: 'LAN',
#   244: 'LAN',
#   245: 'LAN',
#   246: 'LAN',
#   247: 'LAN',
#   248: 'LAN',
#   249: 'LAN',
#   250: 'LAN',
#   251: 'LAN',
#   252: 'LAN',
#   253: 'LAN',
#   254: 'LAN',
#   255: 'LAN',
#   256: 'LAN',
#   257: 'LAN',
#   258: 'LAN',
#   259: 'LAN',
#   260: 'LAN',
#   261: 'LAN',
#   262: 'LAN',
#   263: 'LAN',
#   264: 'LAN',
#   265: 'MIN',
#   266: 'MIN',
#   267: 'MIN',
#   268: 'MIN',
#   269: 'MIN',
#   270: 'MIN',
#   271: 'MIN',
#   272: 'MIN',
#   273: 'MIN',
#   274: 'MIN',
#   275: 'MIN',
#   276: 'MIN',
#   277: 'MIN',
#   278: 'MIN',
#   279: 'MIN',
#   280: 'MIN',
#   281: 'MIN',
#   282: 'MIN',
#   283: 'MIN',
#   284: 'ML4',
#   285: 'ML4',
#   286: 'ML4',
#   287: 'ML4',
#   288: 'ML4',
#   289: 'ML4',
#   290: 'ML4',
#   291: 'ML4',
#   292: 'ML4',
#   293: 'ML4',
#   294: 'ML4',
#   295: 'ML4',
#   296: 'ML4',
#   297: 'ML4',
#   298: 'ML4',
#   299: 'ML4',
#   300: 'ML4',
#   301: 'ML4',
#   302: 'ML4',
#   303: 'MON',
#   304: 'MON',
#   305: 'MON',
#   306: 'MON',
#   307: 'MON',
#   308: 'MON',
#   309: 'MON',
#   310: 'MON',
#   311: 'MON',
#   312: 'MON',
#   313: 'MON',
#   314: 'MON',
#   315: 'MON',
#   316: 'MON',
#   317: 'MON',
#   318: 'MON',
#   319: 'MON',
#   320: 'MON',
#   321: 'MON',
#   322: 'MON',
#   323: 'NYA',
#   324: 'NYA',
#   325: 'NYA',
#   326: 'NYA',
#   327: 'NYA',
#   328: 'NYA',
#   329: 'NYA',
#   330: 'NYA',
#   331: 'NYA',
#   332: 'NYA',
#   333: 'NYA',
#   334: 'NYA',
#   335: 'NYA',
#   336: 'NYA',
#   337: 'NYA',
#   338: 'NYA',
#   339: 'NYA',
#   340: 'NYA',
#   341: 'NYA',
#   342: 'NYA',
#   343: 'NYN',
#   344: 'NYN',
#   345: 'NYN',
#   346: 'NYN',
#   347: 'NYN',
#   348: 'NYN',
#   349: 'NYN',
#   350: 'NYN',
#   351: 'NYN',
#   352: 'NYN',
#   353: 'NYN',
#   354: 'NYN',
#   355: 'NYN',
#   356: 'NYN',
#   357: 'NYN',
#   358: 'NYN',
#   359: 'NYN',
#   360: 'NYN',
#   361: 'NYN',
#   362: 'NYN',
#   363: 'NYN',
#   364: 'OAK',
#   365: 'OAK',
#   366: 'OAK',
#   367: 'OAK',
#   368: 'OAK',
#   369: 'OAK',
#   370: 'OAK',
#   371: 'OAK',
#   372: 'OAK',
#   373: 'OAK',
#   374: 'OAK',
#   375: 'OAK',
#   376: 'OAK',
#   377: 'OAK',
#   378: 'OAK',
#   379: 'OAK',
#   380: 'OAK',
#   381: 'OAK',
#   382: 'OAK',
#   383: 'OAK',
#   384: 'OAK',
#   385: 'PHI',
#   386: 'PHI',
#   387: 'PHI',
#   388: 'PHI',
#   389: 'PHI',
#   390: 'PHI',
#   391: 'PHI',
#   392: 'PHI',
#   393: 'PHI',
#   394: 'PHI',
#   395: 'PHI',
#   396: 'PHI',
#   397: 'PHI',
#   398: 'PHI',
#   399: 'PHI',
#   400: 'PHI',
#   401: 'PHI',
#   402: 'PHI',
#   403: 'PHI',
#   404: 'PIT',
#   405: 'PIT',
#   406: 'PIT',
#   407: 'PIT',
#   408: 'PIT',
#   409: 'PIT',
#   410: 'PIT',
#   411: 'PIT',
#   412: 'PIT',
#   413: 'PIT',
#   414: 'PIT',
#   415: 'PIT',
#   416: 'PIT',
#   417: 'PIT',
#   418: 'PIT',
#   419: 'PIT',
#   420: 'PIT',
#   421: 'PIT',
#   422: 'PIT',
#   423: 'SDN',
#   424: 'SDN',
#   425: 'SDN',
#   426: 'SDN',
#   427: 'SDN',
#   428: 'SDN',
#   429: 'SDN',
#   430: 'SDN',
#   431: 'SDN',
#   432: 'SDN',
#   433: 'SDN',
#   434: 'SDN',
#   435: 'SDN',
#   436: 'SDN',
#   437: 'SDN',
#   438: 'SDN',
#   439: 'SDN',
#   440: 'SDN',
#   441: 'SDN',
#   442: 'SDN',
#   443: 'SDN',
#   444: 'SDN',
#   445: 'SEA',
#   446: 'SEA',
#   447: 'SEA',
#   448: 'SEA',
#   449: 'SEA',
#   450: 'SEA',
#   451: 'SEA',
#   452: 'SEA',
#   453: 'SEA',
#   454: 'SEA',
#   455: 'SEA',
#   456: 'SEA',
#   457: 'SEA',
#   458: 'SEA',
#   459: 'SEA',
#   460: 'SEA',
#   461: 'SEA',
#   462: 'SEA',
#   463: 'SFN',
#   464: 'SFN',
#   465: 'SFN',
#   466: 'SFN',
#   467: 'SFN',
#   468: 'SFN',
#   469: 'SFN',
#   470: 'SFN',
#   471: 'SFN',
#   472: 'SFN',
#   473: 'SFN',
#   474: 'SFN',
#   475: 'SFN',
#   476: 'SFN',
#   477: 'SFN',
#   478: 'SFN',
#   479: 'SFN',
#   480: 'SFN',
#   481: 'SFN',
#   482: 'SFN',
#   483: 'SLN',
#   484: 'SLN',
#   485: 'SLN',
#   486: 'SLN',
#   487: 'SLN',
#   488: 'SLN',
#   489: 'SLN',
#   490: 'SLN',
#   491: 'SLN',
#   492: 'SLN',
#   493: 'SLN',
#   494: 'SLN',
#   495: 'SLN',
#   496: 'SLN',
#   497: 'SLN',
#   498: 'SLN',
#   499: 'SLN',
#   500: 'SLN',
#   501: 'SLN',
#   502: 'SLN',
#   503: 'SLN',
#   504: 'SLN',
#   505: 'SLN',
#   506: 'SLN',
#   507: 'SLN',
#   508: 'TEX',
#   509: 'TEX',
#   510: 'TEX',
#   511: 'TEX',
#   512: 'TEX',
#   513: 'TEX',
#   514: 'TEX',
#   515: 'TEX',
#   516: 'TEX',
#   517: 'TEX',
#   518: 'TEX',
#   519: 'TEX',
#   520: 'TEX',
#   521: 'TEX',
#   522: 'TEX',
#   523: 'TEX',
#   524: 'TEX',
#   525: 'TEX',
#   526: 'TEX',
#   527: 'TEX',
#   528: 'TOR',
#   529: 'TOR',
#   530: 'TOR',
#   531: 'TOR',
#   532: 'TOR',
#   533: 'TOR',
#   534: 'TOR',
#   535: 'TOR',
#   536: 'TOR',
#   537: 'TOR',
#   538: 'TOR',
#   539: 'TOR',
#   540: 'TOR',
#   541: 'TOR',
#   542: 'TOR',
#   543: 'TOR',
#   544: 'TOR',
#   545: 'TOR',
#   546: 'TOR',
#   547: 'TOR',
#   548: 'ATL',
#   549: 'ATL',
#   550: 'ATL',
#   551: 'ATL',
#   552: 'ATL',
#   553: 'ATL',
#   554: 'ATL',
#   555: 'ATL',
#   556: 'ATL',
#   557: 'ATL',
#   558: 'ATL',
#   559: 'ATL',
#   560: 'ATL',
#   561: 'ATL',
#   562: 'ATL',
#   563: 'ATL',
#   564: 'ATL',
#   565: 'ATL',
#   566: 'ATL',
#   567: 'ATL',
#   568: 'ATL',
#   569: 'ATL',
#   570: 'ATL',
#   571: 'ATL',
#   572: 'ATL',
#   573: 'ATL',
#   574: 'ATL',
#   575: 'ATL',
#   576: 'ATL',
#   577: 'BAL',
#   578: 'BAL',
#   579: 'BAL',
#   580: 'BAL',
#   581: 'BAL',
#   582: 'BAL',
#   583: 'BAL',
#   584: 'BAL',
#   585: 'BAL',
#   586: 'BAL',
#   587: 'BAL',
#   588: 'BAL',
#   589: 'BAL',
#   590: 'BAL',
#   591: 'BAL',
#   592: 'BAL',
#   593: 'BAL',
#   594: 'BAL',
#   595: 'BAL',
#   596: 'BAL',
#   597: 'BAL',
#   598: 'BAL',
#   599: 'BAL',
#   600: 'BAL',
#   601: 'BAL',
#   602: 'BAL',
#   603: 'BAL',
#   604: 'BAL',
#   605: 'BAL',
#   606: 'BOS',
#   607: 'BOS',
#   608: 'BOS',
#   609: 'BOS',
#   610: 'BOS',
#   611: 'BOS',
#   612: 'BOS',
#   613: 'BOS',
#   614: 'BOS',
#   615: 'BOS',
#   616: 'BOS',
#   617: 'BOS',
#   618: 'BOS',
#   619: 'BOS',
#   620: 'BOS',
#   621: 'BOS',
#   622: 'BOS',
#   623: 'BOS',
#   624: 'BOS',
#   625: 'BOS',
#   626: 'BOS',
#   627: 'BOS',
#   628: 'BOS',
#   629: 'BOS',
#   630: 'BOS',
#   631: 'BOS',
#   632: 'BOS',
#   633: 'BOS',
#   634: 'BOS',
#   635: 'CAL',
#   636: 'CAL',
#   637: 'CAL',
#   638: 'CAL',
#   639: 'CAL',
#   640: 'CAL',
#   641: 'CAL',
#   642: 'CAL',
#   643: 'CAL',
#   644: 'CAL',
#   645: 'CAL',
#   646: 'CAL',
#   647: 'CAL',
#   648: 'CAL',
#   649: 'CAL',
#   650: 'CAL',
#   651: 'CAL',
#   652: 'CAL',
#   653: 'CAL',
#   654: 'CAL',
#   655: 'CAL',
#   656: 'CAL',
#   657: 'CAL',
#   658: 'CAL',
#   659: 'CAL',
#   660: 'CAL',
#   661: 'CAL',
#   662: 'CAL',
#   663: 'CAL',
#   664: 'CHA',
#   665: 'CHA',
#   666: 'CHA',
#   667: 'CHA',
#   668: 'CHA',
#   669: 'CHA',
#   670: 'CHA',
#   671: 'CHA',
#   672: 'CHA',
#   673: 'CHA',
#   674: 'CHA',
#   675: 'CHA',
#   676: 'CHA',
#   677: 'CHA',
#   678: 'CHA',
#   679: 'CHA',
#   680: 'CHA',
#   681: 'CHA',
#   682: 'CHA',
#   683: 'CHA',
#   684: 'CHA',
#   685: 'CHA',
#   686: 'CHA',
#   687: 'CHA',
#   688: 'CHA',
#   689: 'CHA',
#   690: 'CHA',
#   691: 'CHA',
#   692: 'CHA',
#   693: 'CHA',
#   694: 'CHA',
#   695: 'CHN',
#   696: 'CHN',
#   697: 'CHN',
#   698: 'CHN',
#   699: 'CHN',
#   700: 'CHN',
#   701: 'CHN',
#   702: 'CHN',
#   703: 'CHN',
#   704: 'CHN',
#   705: 'CHN',
#   706: 'CHN',
#   707: 'CHN',
#   708: 'CHN',
#   709: 'CHN',
#   710: 'CHN',
#   711: 'CHN',
#   712: 'CHN',
#   713: 'CHN',
#   714: 'CHN',
#   715: 'CHN',
#   716: 'CHN',
#   717: 'CHN',
#   718: 'CHN',
#   719: 'CHN',
#   720: 'CHN',
#   721: 'CHN',
#   722: 'CHN',
#   723: 'CHN',
#   724: 'CHN',
#   725: 'CHN',
#   726: 'CIN',
#   727: 'CIN',
#   728: 'CIN',
#   729: 'CIN',
#   730: 'CIN',
#   731: 'CIN',
#   732: 'CIN',
#   733: 'CIN',
#   734: 'CIN',
#   735: 'CIN',
#   736: 'CIN',
#   737: 'CIN',
#   738: 'CIN',
#   739: 'CIN',
#   740: 'CIN',
#   741: 'CIN',
#   742: 'CIN',
#   743: 'CIN',
#   744: 'CIN',
#   745: 'CIN',
#   746: 'CIN',
#   747: 'CIN',
#   748: 'CIN',
#   749: 'CIN',
#   750: 'CIN',
#   751: 'CIN',
#   752: 'CIN',
#   753: 'CIN',
#   754: 'CIN',
#   755: 'CIN',
#   756: 'CLE',
#   757: 'CLE',
#   758: 'CLE',
#   759: 'CLE',
#   760: 'CLE',
#   761: 'CLE',
#   762: 'CLE',
#   763: 'CLE',
#   764: 'CLE',
#   765: 'CLE',
#   766: 'CLE',
#   767: 'CLE',
#   768: 'CLE',
#   769: 'CLE',
#   770: 'CLE',
#   771: 'CLE',
#   772: 'CLE',
#   773: 'CLE',
#   774: 'CLE',
#   775: 'CLE',
#   776: 'CLE',
#   777: 'CLE',
#   778: 'CLE',
#   779: 'CLE',
#   780: 'CLE',
#   781: 'CLE',
#   782: 'CLE',
#   783: 'CLE',
#   784: 'CLE',
#   785: 'CLE',
#   786: 'CLE',
#   787: 'DET',
#   788: 'DET',
#   789: 'DET',
#   790: 'DET',
#   791: 'DET',
#   792: 'DET',
#   793: 'DET',
#   794: 'DET',
#   795: 'DET',
#   796: 'DET',
#   797: 'DET',
#   798: 'DET',
#   799: 'DET',
#   800: 'DET',
#   801: 'DET',
#   802: 'DET',
#   803: 'DET',
#   804: 'DET',
#   805: 'DET',
#   806: 'DET',
#   807: 'DET',
#   808: 'DET',
#   809: 'DET',
#   810: 'DET',
#   811: 'DET',
#   812: 'DET',
#   813: 'DET',
#   814: 'HOU',
#   815: 'HOU',
#   816: 'HOU',
#   817: 'HOU',
#   818: 'HOU',
#   819: 'HOU',
#   820: 'HOU',
#   821: 'HOU',
#   822: 'HOU',
#   823: 'HOU',
#   824: 'HOU',
#   825: 'HOU',
#   826: 'HOU',
#   827: 'HOU',
#   828: 'HOU',
#   829: 'HOU',
#   830: 'HOU',
#   831: 'HOU',
#   832: 'HOU',
#   833: 'HOU',
#   834: 'HOU',
#   835: 'HOU',
#   836: 'HOU',
#   837: 'HOU',
#   838: 'KCA',
#   839: 'KCA',
#   840: 'KCA',
#   841: 'KCA',
#   842: 'KCA',
#   843: 'KCA',
#   844: 'KCA',
#   845: 'KCA',
#   846: 'KCA',
#   847: 'KCA',
#   848: 'KCA',
#   849: 'KCA',
#   850: 'KCA',
#   851: 'KCA',
#   852: 'KCA',
#   853: 'KCA',
#   854: 'KCA',
#   855: 'KCA',
#   856: 'KCA',
#   857: 'KCA',
#   858: 'KCA',
#   859: 'KCA',
#   860: 'KCA',
#   861: 'KCA',
#   862: 'KCA',
#   863: 'KCA',
#   864: 'KCA',
#   865: 'KCA',
#   866: 'LAN',
#   867: 'LAN',
#   868: 'LAN',
#   869: 'LAN',
#   870: 'LAN',
#   871: 'LAN',
#   872: 'LAN',
#   873: 'LAN',
#   874: 'LAN',
#   875: 'LAN',
#   876: 'LAN',
#   877: 'LAN',
#   878: 'LAN',
#   879: 'LAN',
#   880: 'LAN',
#   881: 'LAN',
#   882: 'LAN',
#   883: 'LAN',
#   884: 'LAN',
#   885: 'LAN',
#   886: 'LAN',
#   887: 'LAN',
#   888: 'LAN',
#   889: 'LAN',
#   890: 'LAN',
#   891: 'LAN',
#   892: 'LAN',
#   893: 'LAN',
#   894: 'LAN',
#   895: 'LAN',
#   896: 'LAN',
#   897: 'LAN',
#   898: 'MIN',
#   899: 'MIN',
#   900: 'MIN',
#   901: 'MIN',
#   902: 'MIN',
#   903: 'MIN',
#   904: 'MIN',
#   905: 'MIN',
#   906: 'MIN',
#   907: 'MIN',
#   908: 'MIN',
#   909: 'MIN',
#   910: 'MIN',
#   911: 'MIN',
#   912: 'MIN',
#   913: 'MIN',
#   914: 'MIN',
#   915: 'MIN',
#   916: 'MIN',
#   917: 'MIN',
#   918: 'MIN',
#   919: 'MIN',
#   920: 'ML4',
#   921: 'ML4',
#   922: 'ML4',
#   923: 'ML4',
#   924: 'ML4',
#   925: 'ML4',
#   926: 'ML4',
#   927: 'ML4',
#   928: 'ML4',
#   929: 'ML4',
#   930: 'ML4',
#   931: 'ML4',
#   932: 'ML4',
#   933: 'ML4',
#   934: 'ML4',
#   935: 'ML4',
#   936: 'ML4',
#   937: 'ML4',
#   938: 'ML4',
#   939: 'ML4',
#   940: 'ML4',
#   941: 'ML4',
#   942: 'ML4',
#   943: 'ML4',
#   944: 'ML4',
#   945: 'ML4',
#   946: 'ML4',
#   947: 'ML4',
#   948: 'MON',
#   949: 'MON',
#   950: 'MON',
#   951: 'MON',
#   952: 'MON',
#   953: 'MON',
#   954: 'MON',
#   955: 'MON',
#   956: 'MON',
#   957: 'MON',
#   958: 'MON',
#   959: 'MON',
#   960: 'MON',
#   961: 'MON',
#   962: 'MON',
#   963: 'MON',
#   964: 'MON',
#   965: 'MON',
#   966: 'MON',
#   967: 'MON',
#   968: 'MON',
#   969: 'MON',
#   970: 'MON',
#   971: 'MON',
#   972: 'MON',
#   973: 'MON',
#   974: 'MON',
#   975: 'MON',
#   976: 'MON',
#   977: 'MON',
#   978: 'MON',
#   979: 'MON',
#   980: 'NYA',
#   981: 'NYA',
#   982: 'NYA',
#   983: 'NYA',
#   984: 'NYA',
#   985: 'NYA',
#   986: 'NYA',
#   987: 'NYA',
#   988: 'NYA',
#   989: 'NYA',
#   990: 'NYA',
#   991: 'NYA',
#   992: 'NYA',
#   993: 'NYA',
#   994: 'NYA',
#   995: 'NYA',
#   996: 'NYA',
#   997: 'NYA',
#   998: 'NYA',
#   999: 'NYA',
#   ...},
#  'NL': {0: 'NL',
#   1: 'NL',
#   2: 'NL',
#   3: 'NL',
#   4: 'NL',
#   5: 'NL',
#   6: 'NL',
#   7: 'NL',
#   8: 'NL',
#   9: 'NL',
#   10: 'NL',
#   11: 'NL',
#   12: 'NL',
#   13: 'NL',
#   14: 'NL',
#   15: 'NL',
#   16: 'NL',
#   17: 'NL',
#   18: 'NL',
#   19: 'NL',
#   20: 'AL',
#   21: 'AL',
#   22: 'AL',
#   23: 'AL',
#   24: 'AL',
#   25: 'AL',
#   26: 'AL',
#   27: 'AL',
#   28: 'AL',
#   29: 'AL',
#   30: 'AL',
#   31: 'AL',
#   32: 'AL',
#   33: 'AL',
#   34: 'AL',
#   35: 'AL',
#   36: 'AL',
#   37: 'AL',
#   38: 'AL',
#   39: 'AL',
#   40: 'AL',
#   41: 'AL',
#   42: 'AL',
#   43: 'AL',
#   44: 'AL',
#   45: 'AL',
#   46: 'AL',
#   47: 'AL',
#   48: 'AL',
#   49: 'AL',
#   50: 'AL',
#   51: 'AL',
#   52: 'AL',
#   53: 'AL',
#   54: 'AL',
#   55: 'AL',
#   56: 'AL',
#   57: 'AL',
#   58: 'AL',
#   59: 'AL',
#   60: 'AL',
#   61: 'AL',
#   62: 'AL',
#   63: 'AL',
#   64: 'AL',
#   65: 'AL',
#   66: 'AL',
#   67: 'AL',
#   68: 'AL',
#   69: 'AL',
#   70: 'AL',
#   71: 'AL',
#   72: 'AL',
#   73: 'AL',
#   74: 'AL',
#   75: 'AL',
#   76: 'AL',
#   77: 'AL',
#   78: 'AL',
#   79: 'AL',
#   80: 'AL',
#   81: 'AL',
#   82: 'AL',
#   83: 'AL',
#   84: 'AL',
#   85: 'AL',
#   86: 'AL',
#   87: 'AL',
#   88: 'AL',
#   89: 'AL',
#   90: 'AL',
#   91: 'AL',
#   92: 'AL',
#   93: 'AL',
#   94: 'AL',
#   95: 'AL',
#   96: 'AL',
#   97: 'AL',
#   98: 'AL',
#   99: 'AL',
#   100: 'AL',
#   101: 'AL',
#   102: 'AL',
#   103: 'AL',
#   104: 'AL',
#   105: 'AL',
#   106: 'AL',
#   107: 'AL',
#   108: 'AL',
#   109: 'AL',
#   110: 'AL',
#   111: 'AL',
#   112: 'AL',
#   113: 'AL',
# ...
#   913: 'AL',
#   914: 'AL',
#   915: 'AL',
#   916: 'AL',
#   917: 'AL',
#   918: 'AL',
#   919: 'AL',
#   920: 'AL',
#   921: 'AL',
#   922: 'AL',
#   923: 'AL',
#   924: 'AL',
#   925: 'AL',
#   926: 'AL',
#   927: 'AL',
#   928: 'AL',
#   929: 'AL',
#   930: 'AL',
#   931: 'AL',
#   932: 'AL',
#   933: 'AL',
#   934: 'AL',
#   935: 'AL',
#   936: 'AL',
#   937: 'AL',
#   938: 'AL',
#   939: 'AL',
#   940: 'AL',
#   941: 'AL',
#   942: 'AL',
#   943: 'AL',
#   944: 'AL',
#   945: 'AL',
#   946: 'AL',
#   947: 'AL',
#   948: 'NL',
#   949: 'NL',
#   950: 'NL',
#   951: 'NL',
#   952: 'NL',
#   953: 'NL',
#   954: 'NL',
#   955: 'NL',
#   956: 'NL',
#   957: 'NL',
#   958: 'NL',
#   959: 'NL',
#   960: 'NL',
#   961: 'NL',
#   962: 'NL',
#   963: 'NL',
#   964: 'NL',
#   965: 'NL',
#   966: 'NL',
#   967: 'NL',
#   968: 'NL',
#   969: 'NL',
#   970: 'NL',
#   971: 'NL',
#   972: 'NL',
#   973: 'NL',
#   974: 'NL',
#   975: 'NL',
#   976: 'NL',
#   977: 'NL',
#   978: 'NL',
#   979: 'NL',
#   980: 'AL',
#   981: 'AL',
#   982: 'AL',
#   983: 'AL',
#   984: 'AL',
#   985: 'AL',
#   986: 'AL',
#   987: 'AL',
#   988: 'AL',
#   989: 'AL',
#   990: 'AL',
#   991: 'AL',
#   992: 'AL',
#   993: 'AL',
#   994: 'AL',
#   995: 'AL',
#   996: 'AL',
#   997: 'AL',
#   998: 'AL',
#   999: 'AL',
#   ...},
#  '870000': {0: 550000,
#   1: 633333,
#   2: 625000,
#   3: 800000,
#   4: 150000,
#   5: 483333,
#   6: 772000,
#   7: 250000,
#   8: 1500000,
#   9: 455000,
#   10: 407500,
#   11: 275000,
#   12: 775000,
#   13: 1625000,
#   14: 616667,
#   15: 450000,
#   16: 120000,
#   17: 750000,
#   18: 1354167,
#   19: 800000,
#   20: 625000,
#   21: 480000,
#   22: 437500,
#   23: 512500,
#   24: 375000,
#   25: 641667,
#   26: 450000,
#   27: 483333,
#   28: 725000,
#   29: 1090000,
#   30: 560000,
#   31: 440000,
#   32: 547143,
#   33: 1472819,
#   34: 341667,
#   35: 128500,
#   36: 800000,
#   37: 558333,
#   38: 60000,
#   39: 130000,
#   40: 581250,
#   41: 121000,
#   42: 915000,
#   43: 272500,
#   44: 1000000,
#   45: 115000,
#   46: 177500,
#   47: 747500,
#   48: 580000,
#   49: 140000,
#   50: 160000,
#   51: 650000,
#   52: 800000,
#   53: 477500,
#   54: 130000,
#   55: 335000,
#   56: 300000,
#   57: 125000,
#   58: 370000,
#   59: 275000,
#   60: 260000,
#   61: 165000,
#   62: 240000,
#   63: 483333,
#   64: 779227,
#   65: 1075000,
#   66: 325000,
#   67: 365000,
#   68: 883000,
#   69: 856667,
#   70: 612500,
#   71: 875000,
#   72: 60000,
#   73: 360000,
#   74: 1100000,
#   75: 808333,
#   76: 633333,
#   77: 700000,
#   78: 737000,
#   79: 625000,
#   80: 1058894,
#   81: 390000,
#   82: 346667,
#   83: 60000,
#   84: 407500,
#   85: 125000,
#   86: 146500,
#   87: 340000,
#   88: 120000,
#   89: 130000,
#   90: 437500,
#   91: 750000,
#   92: 266667,
#   93: 683333,
#   94: 550000,
#   95: 147500,
#   96: 675000,
#   97: 811250,
#   98: 727500,
#   99: 1242333,
#   100: 900000,
#   101: 685000,
#   102: 165000,
#   103: 60000,
#   104: 150000,
#   105: 200000,
#   106: 265000,
#   107: 300000,
#   108: 565000,
#   109: 463000,
#   110: 110000,
#   111: 333333,
#   112: 325000,
#   113: 1136262,
#   114: 390000,
#   115: 195000,
#   116: 215000,
#   117: 375000,
#   118: 1450000,
#   119: 550000,
#   120: 406250,
#   121: 800000,
#   122: 750000,
#   123: 200000,
#   124: 483333,
#   125: 310000,
#   126: 490000,
#   127: 600000,
#   128: 865000,
#   129: 766667,
#   130: 505000,
#   131: 500000,
#   132: 670000,
#   133: 320000,
#   134: 225000,
#   135: 1260000,
#   136: 640000,
#   137: 321667,
#   138: 751297,
#   139: 60000,
#   140: 920000,
#   141: 117500,
#   142: 75000,
#   143: 833333,
#   144: 250000,
#   145: 110000,
#   146: 300000,
#   147: 550000,
#   148: 970000,
#   149: 350000,
#   150: 225000,
#   151: 255000,
#   152: 410000,
#   153: 227500,
#   154: 358858,
#   155: 1071429,
#   156: 250000,
#   157: 60000,
#   158: 60000,
#   159: 155000,
#   160: 303333,
#   161: 225000,
#   162: 400000,
#   163: 650000,
#   164: 425000,
#   165: 115000,
#   166: 110000,
#   167: 265000,
#   168: 190000,
#   169: 455000,
#   170: 200000,
#   171: 210000,
#   172: 458333,
#   173: 225000,
#   174: 140000,
#   175: 295000,
#   176: 285000,
#   177: 1100000,
#   178: 375000,
#   179: 125000,
#   180: 240000,
#   181: 262500,
#   182: 250000,
#   183: 76000,
#   184: 1083333,
#   185: 685000,
#   186: 250000,
#   187: 660000,
#   188: 675000,
#   189: 380000,
#   190: 670000,
#   191: 575000,
#   192: 885000,
#   193: 766667,
#   194: 875000,
#   195: 100000,
#   196: 177500,
#   197: 517143,
#   198: 670000,
#   199: 550000,
#   200: 416667,
#   201: 155000,
#   202: 291667,
#   203: 796383,
#   204: 60000,
#   205: 295000,
#   206: 255000,
#   207: 325000,
#   208: 745000,
#   209: 850000,
#   210: 700000,
#   211: 825000,
#   212: 541667,
#   213: 350000,
#   214: 1350000,
#   215: 360000,
#   216: 500000,
#   217: 160000,
#   218: 675000,
#   219: 341667,
#   220: 205000,
#   221: 358000,
#   222: 465000,
#   223: 1000000,
#   224: 250000,
#   225: 115000,
#   226: 95000,
#   227: 202500,
#   228: 100000,
#   229: 535000,
#   230: 225000,
#   231: 871429,
#   232: 800000,
#   233: 155500,
#   234: 450000,
#   235: 316667,
#   236: 975000,
#   237: 150000,
#   238: 175000,
#   239: 608333,
#   240: 425000,
#   241: 843750,
#   242: 330000,
#   243: 150000,
#   244: 120000,
#   245: 60000,
#   246: 500000,
#   247: 1270000,
#   248: 212000,
#   249: 705000,
#   250: 150000,
#   251: 537500,
#   252: 140000,
#   253: 333000,
#   254: 370000,
#   255: 750000,
#   256: 350000,
#   257: 980000,
#   258: 450000,
#   259: 465000,
#   260: 435000,
#   261: 1200000,
#   262: 643750,
#   263: 316667,
#   264: 500000,
#   265: 62500,
#   266: 425000,
#   267: 120000,
#   268: 320000,
#   269: 550000,
#   270: 650000,
#   271: 215000,
#   272: 120000,
#   273: 415000,
#   274: 293750,
#   275: 560000,
#   276: 145000,
#   277: 130000,
#   278: 60000,
#   279: 150000,
#   280: 728571,
#   281: 335000,
#   282: 110000,
#   283: 375000,
#   284: 581250,
#   285: 1176190,
#   286: 565000,
#   287: 1065000,
#   288: 687500,
#   289: 679167,
#   290: 60000,
#   291: 215000,
#   292: 510000,
#   293: 480000,
#   294: 950000,
#   295: 365000,
#   296: 560000,
#   297: 290000,
#   298: 100000,
#   299: 1000000,
#   300: 540000,
#   301: 460000,
#   302: 1000000,
#   303: 550000,
#   304: 1033333,
#   305: 175000,
#   306: 60000,
#   307: 350000,
#   308: 250000,
#   309: 700000,
#   310: 375000,
#   311: 650000,
#   312: 513500,
#   313: 105000,
#   314: 375000,
#   315: 1200000,
#   316: 850000,
#   317: 95000,
#   318: 375000,
#   319: 290000,
#   320: 565000,
#   321: 650000,
#   322: 308333,
#   323: 810000,
#   324: 477500,
#   325: 250000,
#   326: 120000,
#   327: 1075000,
#   328: 900000,
#   329: 425000,
#   330: 1470000,
#   331: 1420000,
#   332: 455000,
#   333: 100000,
#   334: 637500,
#   335: 600000,
#   336: 600000,
#   337: 680000,
#   338: 435000,
#   339: 637500,
#   340: 800000,
#   341: 1795704,
#   342: 550000,
#   343: 200000,
#   344: 325000,
#   345: 525000,
#   346: 2028571,
#   347: 230000,
#   348: 1942857,
#   349: 100000,
#   350: 450000,
#   351: 150000,
#   352: 260000,
#   353: 1100000,
#   354: 115000,
#   355: 560000,
#   356: 330000,
#   357: 60000,
#   358: 650000,
#   359: 125000,
#   360: 275000,
#   361: 300000,
#   362: 516667,
#   363: 591667,
#   364: 107333,
#   365: 575000,
#   366: 60000,
#   367: 350000,
#   368: 141500,
#   369: 700000,
#   370: 305000,
#   371: 610000,
#   372: 425000,
#   373: 150000,
#   374: 262500,
#   375: 600000,
#   376: 1087500,
#   377: 608333,
#   378: 900000,
#   379: 520000,
#   380: 845833,
#   381: 283107,
#   382: 220000,
#   383: 100000,
#   384: 207500,
#   385: 237000,
#   386: 250500,
#   387: 1075000,
#   388: 220000,
#   389: 1109333,
#   390: 620000,
#   391: 350000,
#   392: 140000,
#   393: 500000,
#   394: 192500,
#   395: 60000,
#   396: 600000,
#   397: 310000,
#   398: 820333,
#   399: 700000,
#   400: 220000,
#   401: 240000,
#   402: 2130300,
#   403: 350000,
#   404: 255000,
#   405: 155000,
#   406: 150000,
#   407: 129166,
#   408: 425000,
#   409: 975500,
#   410: 600000,
#   411: 796667,
#   412: 232500,
#   413: 60000,
#   414: 1075000,
#   415: 632000,
#   416: 200000,
#   417: 645000,
#   418: 520000,
#   419: 350000,
#   420: 830000,
#   421: 1066667,
#   422: 130000,
#   423: 140000,
#   424: 150000,
#   425: 160000,
#   426: 240000,
#   427: 175000,
#   428: 975000,
#   429: 1713333,
#   430: 440000,
#   431: 200000,
#   432: 975000,
#   433: 340000,
#   434: 870000,
#   435: 270000,
#   436: 140000,
#   437: 150000,
#   438: 900000,
#   439: 325000,
#   440: 537500,
#   441: 556250,
#   442: 1137000,
#   443: 130000,
#   444: 512500,
#   445: 470000,
#   446: 437500,
#   447: 125000,
#   448: 400000,
#   449: 225000,
#   450: 310000,
#   451: 183000,
#   452: 160000,
#   453: 228000,
#   454: 97000,
#   455: 114400,
#   456: 175000,
#   457: 180000,
#   458: 71600,
#   459: 690000,
#   460: 315000,
#   461: 159000,
#   462: 272500,
#   463: 250000,
#   464: 385000,
#   465: 60000,
#   466: 550000,
#   467: 195000,
#   468: 767500,
#   469: 85000,
#   470: 135000,
#   471: 170000,
#   472: 275000,
#   473: 355000,
#   474: 630000,
#   475: 355000,
#   476: 500000,
#   477: 900000,
#   478: 865000,
#   479: 197000,
#   480: 462500,
#   481: 709714,
#   482: 375000,
#   483: 750000,
#   484: 1030000,
#   485: 160000,
#   486: 457500,
#   487: 562500,
#   488: 1555000,
#   489: 60000,
#   490: 110000,
#   491: 150000,
#   492: 700000,
#   493: 583333,
#   494: 135000,
#   495: 560000,
#   496: 110000,
#   497: 200000,
#   498: 100000,
#   499: 250000,
#   500: 208750,
#   501: 475000,
#   502: 112500,
#   503: 740000,
#   504: 740000,
#   505: 1440000,
#   506: 457500,
#   507: 170000,
#   508: 350000,
#   509: 650000,
#   510: 565000,
#   511: 636667,
#   512: 683333,
#   513: 117500,
#   514: 60000,
#   515: 235000,
#   516: 165000,
#   517: 560000,
#   518: 310000,
#   519: 344000,
#   520: 215000,
#   521: 250000,
#   522: 505000,
#   523: 590000,
#   524: 135000,
#   525: 185000,
#   526: 720000,
#   527: 400000,
#   528: 170000,
#   529: 875000,
#   530: 325000,
#   531: 335000,
#   532: 350000,
#   533: 833333,
#   534: 580000,
#   535: 127500,
#   536: 740000,
#   537: 60000,
#   538: 256667,
#   539: 131250,
#   540: 475000,
#   541: 356300,
#   542: 185000,
#   543: 587500,
#   544: 325000,
#   545: 1000000,
#   546: 730000,
#   547: 370000,
#   548: 367500,
#   549: 60000,
#   550: 880000,
#   551: 565000,
#   552: 600000,
#   553: 769452,
#   554: 200000,
#   555: 786667,
#   556: 425000,
#   557: 1800000,
#   558: 505000,
#   559: 105000,
#   560: 687500,
#   561: 225000,
#   562: 100000,
#   563: 257500,
#   564: 1825000,
#   565: 825000,
#   566: 60000,
#   567: 390000,
#   568: 825000,
#   569: 470000,
#   570: 1000000,
#   571: 200000,
#   572: 60000,
#   573: 1729167,
#   574: 60000,
#   575: 575000,
#   576: 750000,
#   577: 600000,
#   578: 450000,
#   579: 837500,
#   580: 120000,
#   581: 250000,
#   582: 510000,
#   583: 442066,
#   584: 140000,
#   585: 400000,
#   586: 639791,
#   587: 350000,
#   588: 450000,
#   589: 167500,
#   590: 115000,
#   591: 107500,
#   592: 725000,
#   593: 1190000,
#   594: 560458,
#   595: 487078,
#   596: 911051,
#   597: 925814,
#   598: 285000,
#   599: 310000,
#   600: 1150000,
#   601: 120000,
#   602: 240000,
#   603: 70000,
#   604: 60000,
#   605: 387500,
#   606: 1000000,
#   607: 435000,
#   608: 660696,
#   609: 1350000,
#   610: 375000,
#   611: 80000,
#   612: 785000,
#   613: 340000,
#   614: 330000,
#   615: 1017757,
#   616: 70000,
#   617: 650000,
#   618: 60000,
#   619: 412000,
#   620: 350000,
#   621: 495000,
#   622: 541250,
#   623: 265000,
#   624: 255000,
#   625: 60000,
#   626: 1984423,
#   627: 375000,
#   628: 500000,
#   629: 75000,
#   630: 1060000,
#   631: 300000,
#   632: 381113,
#   633: 110000,
#   634: 85000,
#   635: 853479,
#   636: 856667,
#   637: 800000,
#   638: 410000,
#   639: 1200000,
#   640: 808333,
#   641: 60000,
#   642: 100000,
#   643: 170000,
#   644: 500000,
#   645: 939333,
#   646: 82500,
#   647: 1102946,
#   648: 440000,
#   649: 560000,
#   650: 65000,
#   651: 500000,
#   652: 142000,
#   653: 1000000,
#   654: 142000,
#   655: 300000,
#   656: 425000,
#   657: 60000,
#   658: 210000,
#   659: 400000,
#   660: 890000,
#   661: 60000,
#   662: 416667,
#   663: 933333,
#   664: 900000,
#   665: 775000,
#   666: 930000,
#   667: 115000,
#   668: 68000,
#   669: 66500,
#   670: 60000,
#   671: 60000,
#   672: 295000,
#   673: 600000,
#   674: 975000,
#   675: 875000,
#   676: 60000,
#   677: 80000,
#   678: 150000,
#   679: 156667,
#   680: 200000,
#   681: 195000,
#   682: 555000,
#   683: 60000,
#   684: 400000,
#   685: 60000,
#   686: 60000,
#   687: 240000,
#   688: 150000,
#   689: 465000,
#   690: 1132652,
#   691: 75000,
#   692: 200000,
#   693: 60000,
#   694: 400000,
#   695: 327500,
#   696: 575000,
#   697: 1400000,
#   698: 833333,
#   699: 558333,
#   700: 100000,
#   701: 983333,
#   702: 783333,
#   703: 240000,
#   704: 250000,
#   705: 633333,
#   706: 64000,
#   707: 100000,
#   708: 100000,
#   709: 60000,
#   710: 490000,
#   711: 60000,
#   712: 850000,
#   713: 760000,
#   714: 60000,
#   715: 850000,
#   716: 1050000,
#   717: 325000,
#   718: 665000,
#   719: 800000,
#   720: 720000,
#   721: 275000,
#   722: 1530000,
#   723: 550000,
#   724: 890000,
#   725: 325000,
#   726: 870000,
#   727: 215000,
#   728: 102500,
#   729: 920000,
#   730: 60000,
#   731: 90000,
#   732: 1083333,
#   733: 775000,
#   734: 272500,
#   735: 195000,
#   736: 545555,
#   737: 60000,
#   738: 60000,
#   739: 60000,
#   740: 350000,
#   741: 60000,
#   742: 650000,
#   743: 1100000,
#   744: 405000,
#   745: 275000,
#   746: 500000,
#   747: 430000,
#   748: 92500,
#   749: 1000000,
#   750: 1150000,
#   751: 60000,
#   752: 150000,
#   753: 225000,
#   754: 80000,
#   755: 70000,
#   756: 60000,
#   757: 60000,
#   758: 225000,
#   759: 580000,
#   760: 850000,
#   761: 145000,
#   762: 80000,
#   763: 190000,
#   764: 177500,
#   765: 350000,
#   766: 575000,
#   767: 215000,
#   768: 350000,
#   769: 310000,
#   770: 437500,
#   771: 90000,
#   772: 60000,
#   773: 300000,
#   774: 97500,
#   775: 110000,
#   776: 65000,
#   777: 60000,
#   778: 275000,
#   779: 110000,
#   780: 60000,
#   781: 60000,
#   782: 395000,
#   783: 1100000,
#   784: 270000,
#   785: 92000,
#   786: 60000,
#   787: 316667,
#   788: 325000,
#   789: 200000,
#   790: 75000,
#   791: 700000,
#   792: 793333,
#   793: 1200000,
#   794: 250000,
#   795: 960000,
#   796: 687500,
#   797: 60000,
#   798: 72500,
#   799: 550000,
#   800: 698571,
#   801: 62500,
#   802: 875000,
#   803: 80000,
#   804: 850000,
#   805: 875000,
#   806: 150000,
#   807: 60000,
#   808: 60000,
#   809: 662500,
#   810: 260000,
#   811: 275000,
#   812: 567143,
#   813: 670000,
#   814: 60000,
#   815: 525000,
#   816: 310000,
#   817: 95000,
#   818: 755000,
#   819: 120000,
#   820: 325000,
#   821: 65000,
#   822: 280000,
#   823: 550000,
#   824: 600000,
#   825: 80000,
#   826: 65000,
#   827: 1000000,
#   828: 223275,
#   829: 60000,
#   830: 85000,
#   831: 850000,
#   832: 416667,
#   833: 1125000,
#   834: 666667,
#   835: 650000,
#   836: 600000,
#   837: 366667,
#   838: 525000,
#   839: 60000,
#   840: 165000,
#   841: 645000,
#   842: 1471429,
#   843: 60000,
#   844: 85000,
#   845: 250000,
#   846: 67000,
#   847: 100000,
#   848: 175000,
#   849: 185000,
#   850: 60000,
#   851: 360000,
#   852: 770000,
#   853: 883333,
#   854: 650000,
#   855: 450000,
#   856: 293808,
#   857: 150000,
#   858: 925000,
#   859: 925000,
#   860: 75000,
#   861: 1000000,
#   862: 653128,
#   863: 400000,
#   864: 485000,
#   865: 1175000,
#   866: 200000,
#   867: 375000,
#   868: 200000,
#   869: 325000,
#   870: 450000,
#   871: 200000,
#   872: 150000,
#   873: 65000,
#   874: 1370000,
#   875: 60000,
#   876: 1000000,
#   877: 60000,
#   878: 755000,
#   879: 175000,
#   880: 637500,
#   881: 841667,
#   882: 650000,
#   883: 220000,
#   884: 531250,
#   885: 350000,
#   886: 62000,
#   887: 1000000,
#   888: 450000,
#   889: 584624,
#   890: 800000,
#   891: 65000,
#   892: 409485,
#   893: 1600000,
#   894: 455000,
#   895: 68500,
#   896: 743750,
#   897: 60000,
#   898: 65000,
#   899: 1450000,
#   900: 740000,
#   901: 220000,
#   902: 385000,
#   903: 725000,
#   904: 60000,
#   905: 515000,
#   906: 100000,
#   907: 666667,
#   908: 1060000,
#   909: 115000,
#   910: 155000,
#   911: 75000,
#   912: 60000,
#   913: 62500,
#   914: 255000,
#   915: 60000,
#   916: 115000,
#   917: 740000,
#   918: 450000,
#   919: 674000,
#   920: 60000,
#   921: 60000,
#   922: 60000,
#   923: 675000,
#   924: 671560,
#   925: 60000,
#   926: 607322,
#   927: 610000,
#   928: 95000,
#   929: 887500,
#   930: 779167,
#   931: 195000,
#   932: 60000,
#   933: 90000,
#   934: 495000,
#   935: 487500,
#   936: 1160000,
#   937: 402500,
#   938: 70000,
#   939: 766593,
#   940: 60000,
#   941: 175000,
#   942: 155000,
#   943: 121500,
#   944: 60000,
#   945: 60000,
#   946: 70000,
#   947: 950000,
#   948: 80000,
#   949: 650000,
#   950: 160000,
#   951: 1047000,
#   952: 147000,
#   953: 325000,
#   954: 67500,
#   955: 170000,
#   956: 65000,
#   957: 65000,
#   958: 320000,
#   959: 450000,
#   960: 850000,
#   961: 180000,
#   962: 62500,
#   963: 90000,
#   964: 1515000,
#   965: 850000,
#   966: 60000,
#   967: 138100,
#   968: 415000,
#   969: 61500,
#   970: 700000,
#   971: 1000000,
#   972: 170000,
#   973: 127500,
#   974: 60000,
#   975: 650000,
#   976: 120000,
#   977: 87500,
#   978: 350000,
#   979: 70000,
#   980: 557500,
#   981: 750000,
#   982: 60000,
#   983: 658333,
#   984: 65000,
#   985: 200000,
#   986: 120000,
#   987: 1050000,
#   988: 975000,
#   989: 400873,
#   990: 1570000,
#   991: 60000,
#   992: 1220000,
#   993: 1375000,
#   994: 716667,
#   995: 500000,
#   996: 750000,
#   997: 120000,
#   998: 70000,
#   999: 1060000,
#   ...}}

# %% [markdown]
# (g) Create a dataframe using pd.DataFrameRead (Documentation Link) and from
# the dictionary created in (e). Then, change the header to "a", "b", "c", ... .

# %%
res_atl
# Out:
#         playerID  1985  ATL  NL   870000
# 0      bedrost01  1985  ATL  NL   550000
# 1       campri01  1985  ATL  NL   633333
# 2      ceronri01  1985  ATL  NL   625000
# 3      chambch01  1985  ATL  NL   800000
# 4      dedmoje01  1985  ATL  NL   150000
# ...          ...   ...  ...  ..      ...
# 24804  simmoan01  2015  ATL  NL  3000000
# 24805  teherju01  2015  ATL  NL  1000000
# 24806  terdojo01  2015  ATL  NL   507500
# 24807   woodal02  2015  ATL  NL   520000
# 24808  younger03  2015  ATL  NL  1000000
#
# [884 rows x 5 columns]

# %%
res_atl = res_atl.rename(columns ={'playerID': 'a', '1985':'b','ATL':'c','NL':'d','870000':'e'})
res_atl
# Out:
#                a     b    c   d        e
# 0      bedrost01  1985  ATL  NL   550000
# 1       campri01  1985  ATL  NL   633333
# 2      ceronri01  1985  ATL  NL   625000
# 3      chambch01  1985  ATL  NL   800000
# 4      dedmoje01  1985  ATL  NL   150000
# ...          ...   ...  ...  ..      ...
# 24804  simmoan01  2015  ATL  NL  3000000
# 24805  teherju01  2015  ATL  NL  1000000
# 24806  terdojo01  2015  ATL  NL   507500
# 24807   woodal02  2015  ATL  NL   520000
# 24808  younger03  2015  ATL  NL  1000000
#
# [884 rows x 5 columns]

# %% [markdown]
# ## Numpy

# %% [markdown]
# (a) Create a 2-dimensional Python list object, then convert it to a Numpy array
# object.

# %%
import numpy as np

# %%
p_list =[[1,2,3,4],[5,6,7,8]]
n_arr=np.array(p_list)
print(p_list)
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
print(n_arr)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %% [markdown]
# (b) Examine the ndim, shape, size, dtype, itemsize, and data attributes of the numpy
# array object. Make sure you understand their functions.

# %%
n_arr.ndim
# Out:
# 2

# %%
n_arr.shape
# Out:
# (2, 4)

# %%
n_arr.size
# Out:
# 8

# %%
n_arr.dtype
# Out:
# dtype('int32')

# %%
n_arr.itemsize
# Out:
# 4

# %%
n_arr.data

# %% [markdown]
# (c) Learn the dimension concept of an ndarray object by using reshape() and flatten()
# methods.

# %%
 new= n_arr.reshape(4,2)

# %%
new.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# (d) Understand how the slice operation works for 1-D arrays and 2-D arrays and
# practice by yourself.

# %%
n_arr[0:4,0]
# each row in the firt column of n_arr
# Out:
# array([1, 5])

# %% [markdown]
# (e) Learn operations on ndarray by examining the argmin(), argmax(), min(), max(),
# mean(), sum(), std(), dot(), square(), sqrt(), abs(). exp(

# %%
n_arr.argmin()
# Out:
# 0

# %%
n_arr.argmax()
# Out:
# 7

# %%
n_arr.min()
# Out:
# 1

# %%
n_arr.max()
# Out:
# 8

# %%
n_arr.mean()
# Out:
# 4.5

# %%
n_arr.sum()
# Out:
# 36

# %%
n_arr.std()
# Out:
# 2.29128784747792

# %% [markdown]
# (f) Examine the arange(), ones(), zeros(), eye(), linspace(), and concatenate() methods. Make yourself comfortable with these methods.

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# (a) Create two one dimensional arrays x and y and plot y vs x, add title, xlabel, ylabel, grid.

# %%
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])

# %%
y
# Out:
# array([25.        , 20.01385042, 15.58171745, 11.70360111,  8.37950139,
#         5.60941828,  3.3933518 ,  1.73130194,  0.6232687 ,  0.06925208,
#         0.06925208,  0.6232687 ,  1.73130194,  3.3933518 ,  5.60941828,
#         8.37950139, 11.70360111, 15.58171745, 20.01385042, 25.        ])

# %%
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('2-d array plot')
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
np.random.shuffle(x)
y = np.array([j ** 2 for j in x])

# %%
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('2-d array plot new')
plt.grid(True)

# %% [markdown]
# *here the points were not sorted so random connection took place*

# %% [markdown]
# (b) Create multiple arrays and plot them with different styles, add legends, add text/mathematical equations on the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

# %%
plt.plot(x,y1,'r--')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(x,y2,'bs')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.plot(x,y2,'g^')
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# ## Pandas's DataFrame.plot and Seaborn

# %% [markdown]
# (a) For team 'ATL', plot a scatter plot between feature yearID and salary.

# %%
import seaborn as sns

# %%
res_atl
# plot b and e column
# Out:
#                a     b    c   d        e
# 0      bedrost01  1985  ATL  NL   550000
# 1       campri01  1985  ATL  NL   633333
# 2      ceronri01  1985  ATL  NL   625000
# 3      chambch01  1985  ATL  NL   800000
# 4      dedmoje01  1985  ATL  NL   150000
# ...          ...   ...  ...  ..      ...
# 24804  simmoan01  2015  ATL  NL  3000000
# 24805  teherju01  2015  ATL  NL  1000000
# 24806  terdojo01  2015  ATL  NL   507500
# 24807   woodal02  2015  ATL  NL   520000
# 24808  younger03  2015  ATL  NL  1000000
#
# [884 rows x 5 columns]

# %%
sns.lmplot('b', 'e', data=res_atl, fit_reg=False)

# %% [markdown]
# (b) For year 1985, plot a bar chart to show the average salary for each team.

# %%
year_res= res_atl[res_atl.b==1985]
year_res
# Out:
#             a     b    c   d        e
# 0   bedrost01  1985  ATL  NL   550000
# 1    campri01  1985  ATL  NL   633333
# 2   ceronri01  1985  ATL  NL   625000
# 3   chambch01  1985  ATL  NL   800000
# 4   dedmoje01  1985  ATL  NL   150000
# 5   forstte01  1985  ATL  NL   483333
# 6   garbege01  1985  ATL  NL   772000
# 7   harpete01  1985  ATL  NL   250000
# 8   hornebo01  1985  ATL  NL  1500000
# 9   hubbagl01  1985  ATL  NL   455000
# 10  mahleri01  1985  ATL  NL   407500
# 11  mcmurcr01  1985  ATL  NL   275000
# 12  mumphje01  1985  ATL  NL   775000
# 13  murphda05  1985  ATL  NL  1625000
# 14  oberkke01  1985  ATL  NL   616667
# 15  perezpa01  1985  ATL  NL   450000
# 16  perryge01  1985  ATL  NL   120000
# 17  ramirra01  1985  ATL  NL   750000
# 18  suttebr01  1985  ATL  NL  1354167
# 19  washicl01  1985  ATL  NL   800000

# %% [markdown]
# (c) For team 'ATL', plot a line chart to show how the annual average salary change by years.

# %%
sns.barplot(x = 'b',
            y = 'e',
            data = year_res)
# Out:
# <AxesSubplot:xlabel='b', ylabel='e'>

# %% [markdown]
# ## Github

# %%
git init
# Out:
#   File "<ipython-input-239-f188d5ac1197>", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
